# %%
import torch,os
import torch.optim as optim
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
from utils.data import RandomNoiseGenerator,Data
from utils.train_history import train_history
from utils import visualizer
import itertools
from models.model import Generator, Discriminator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')
if torch.backends.cudnn.enabled:
    torch.backends.cudnn.benchmark = True
device
# Out:
# device(type='cuda', index=3)

# %%
latent_size = 1024
target_resol = 256
first_resol = 4
use_sigmoid = False
train_kimg = 600
train_img = train_kimg*1000
transition_kimg = 600
transition_img = transition_kimg*1000

g_lr_max = 0.001
d_lr_max = 0.001

beta1 = 0
beta2 = 0.99

lambda_A=10
lambda_B=10
lambda_recon=0.8
lambda_idt=0.1

report_it = 400
show_it = 400
save_it=400

# %%
display_id=1
display_winsize=256
display_ncols=4
display_server='http://localhost'
display_port=8097
display_env='pggan'
results_dir='results'
project_name = 'pggan1'
project_dir=os.path.join(results_dir,project_name)

vis = visualizer.Visualizer(display_id,display_winsize,display_ncols,display_server,display_port,display_env,
                 name,results_dir)

if not os.path.isdir(project_dir):
    os.makedirs(project_dir)

# %%
real_dir = '/data/persona_cyclegan/real/trainA'
anime_dir = '/data/persona_cyclegan/anime/trainB'

data_A = Data(real_dir)
data_B = Data(anime_dir)

# %%
G_A = Generator(num_channels=3, latent_size=latent_size, resolution=target_resol, fmap_max=latent_size, fmap_base=8192, tanh_at_end=True)
G_B = Generator(num_channels=3, latent_size=latent_size, resolution=target_resol, fmap_max=latent_size, fmap_base=8192, tanh_at_end=True)

D_A = Discriminator(num_channels=3, mbstat_avg='all', resolution=target_resol, fmap_max=latent_size, fmap_base=8192, sigmoid_at_end=True)
D_B = Discriminator(num_channels=3, mbstat_avg='all', resolution=target_resol, fmap_max=latent_size, fmap_base=8192, sigmoid_at_end=True)

# print(G_A)
# print(D_A)
G_A,G_B,D_A,D_B = G_A.to(device),G_B.to(device),D_A.to(device),D_B.to(device)
optim_G = optim.Adam(itertools.chain(G_A.parameters(),G_B.parameters()), g_lr_max, betas=(beta1, beta2))
optim_D = optim.Adam(itertools.chain(D_A.parameters(),D_B.parameters()), d_lr_max, betas=(beta1, beta2))

all_models = {'G_A.pkl':G_A,
             'G_B.pkl':G_B,
             'D_A.pkl':D_A,
             'D_B.pkl':D_B}
            

print('---------- Networks initialized -------------')
for model_name,model in [('G',G_A),('D',D_A)]:
    num_params = 0
    for param in model.parameters():
        num_params += param.numel()
    print(str.format('{} has {} number of parameters', model_name, num_params))
print('-----------------------------------------------')
# Out:
# ---------- Networks initialized -------------
# G has 149458133 number of parameters
# D has 66632259 number of parameters
# -----------------------------------------------

# %%
rampup_kimg = 10000
rampdown_kimg = 10000
total_kimg = 10000

def _rampup(epoch, rampup_length):
    if epoch < rampup_length:
        p = max(0.0, float(epoch)) / float(rampup_length)
        p = 1.0 - p
        return np.exp(-p*p*5.0)
    else:
        return 1.0

def _rampdown_linear(epoch, num_epochs, rampdown_length):
    if epoch >= num_epochs - rampdown_length:
        return float(num_epochs - epoch) / rampdown_length
    else:
        return 1.0

# %%
def get_bs(resolution):
    R = int(np.log2(resolution))
    if R < 7:
        bs = 32 / 2**(max(0, R-4))
    else:
        bs = 8 / 2**(min(2, R-7))
    return int(bs)

bs_map = {2**R: get_bs(2**R) for R in range(2, 11)}

# %%
train_hist = train_history(['G_gan_loss',
                                          'G_idt_loss',
                                          'G_cycle_loss',
                                          'D_A_loss',
                                          'D_B_loss',                                         
                                          ])

# %%
L1_loss = nn.L1Loss().to(device)

# %%
def save_models(models, folder):
    for k, v in models.items():
        torch.save(v.state_dict(), os.path.join(folder, k))

# %% [markdown]
# ## Train

# %%
to_level = int(np.log2(target_resol))
from_level = int(np.log2(first_resol))

for R in range(from_level-1, to_level):
    
    batch_size = bs_map[2 ** (R+1)]
    phases = {'stabilize':[0, train_img//batch_size], 'fade_in':[train_img//batch_size+1, (transition_img+train_img)//batch_size]}

    for phase in ['stabilize', 'fade_in']:
        if phase in phases:
            _range = phases[phase]
            from_it = _range[0]
            cur_it = 0
            total_it = _range[1]
            remaining_it = total_it-from_it
            cur_nimg = _range[0]*batch_size
            resol = 2 ** (R+1)
            
            previous_time = time.time()
            phase_start_time = time.time()
            
            for it in range(from_it, total_it):
                cur_it += 1
                if phase == 'stabilize':
                    cur_level = R
                else:
                    cur_level = R + cur_it/remaining_it
                cur_resol = 2 ** int(np.ceil(cur_level+1))

                # get a batch noise and real images
                real_A_cur, real_A_max = data_A.next(batch_size,cur_resol,cur_level)
                real_A_cur, real_A_max = real_A_cur.to(device), real_A_max.to(device)
                
                real_B_cur, real_B_max = data_B.next(batch_size,cur_resol,cur_level)
                real_B_cur, real_B_max = real_B_cur.to(device), real_B_max.to(device)
                # ===preprocess===
                for param_group in optim_G.param_groups:
                    lrate_coef = _rampup(cur_nimg / 1000.0, rampup_kimg)
                    lrate_coef *= _rampdown_linear(cur_nimg / 1000.0,total_kimg, rampdown_kimg)
                    param_group['lr'] = lrate_coef * g_lr_max
                for param_group in optim_D.param_groups:
                    lrate_coef = _rampup(cur_nimg / 1000.0, rampup_kimg)
                    lrate_coef *= _rampdown_linear(cur_nimg / 1000.0, total_kimg, rampdown_kimg)
                    param_group['lr'] = lrate_coef * d_lr_max

                # ===update D===
                for model in [D_A,D_B]:
                    for param in model.parameters():
                        param.requires_grad = True
                        
                optim_D.zero_grad()

                fake_B = G_A(real_A_max, cur_level=cur_level)
                d_real_B = D_B(real_B_cur, cur_level=cur_level)
                d_fake_B = D_B(fake_B.detach(), cur_level=cur_level)

                d_real_B_loss = torch.mean((d_real_B-1)**2)
                d_fake_B_loss = torch.mean((d_fake_B-0)**2)
                 
                d_loss_B = 0.5 * (d_real_B_loss + d_fake_B_loss)
                d_loss_B.backward()
 
                fake_A = G_B(real_B_max, cur_level=cur_level)
                d_real_A = D_A(real_A_cur, cur_level=cur_level)
                d_fake_A = D_A(fake_A.detach(), cur_level=cur_level)

                d_real_A_loss = torch.mean((d_real_A-1)**2)
                d_fake_A_loss = torch.mean((d_fake_A-0)**2)
                 
                d_loss_A = 0.5 * (d_real_A_loss + d_fake_A_loss)
                d_loss_A.backward()
                
                optim_D.step()

                # ===update G===
                for model in [D_A,D_B]:
                    for param in model.parameters():
                        param.requires_grad = False
                        
                optim_G.zero_grad()
                
                d_fake_A = D_B(fake_B, cur_level=cur_level)
                d_fake_A_loss = torch.mean((d_fake_A-1)**2)
                
                sim_A_loss = L1_loss(fake_B,real_A_cur) * lambda_idt
                
                recon_A = G_B(fake_B,cur_level=cur_level)
                recon_A_loss = L1_loss(recon_A,real_A_cur) * lambda_recon
                
                G_A_loss = (d_fake_A_loss+sim_A_loss+recon_A_loss)*lambda_A
                G_A_loss.backward()
                
                d_fake_B = D_A(fake_A,cur_level=cur_level)
                d_fake_B_loss = torch.mean((d_fake_B-1)**2)
                
                sim_B_loss = L1_loss(fake_A,real_B_cur)*lambda_idt
                
                recon_B = G_A(fake_A,cur_level=cur_level)
                recon_B_loss = L1_loss(recon_B,real_B_cur)*lambda_recon
                
                G_B_loss = (d_fake_B_loss + sim_B_loss + recon_B_loss)*lambda_B
                G_B_loss.backward()
                
                G_gan_loss = d_fake_A_loss + d_fake_B_loss
                G_idt_loss = sim_A_loss + sim_B_loss
                G_recon_loss = recon_A_loss + recon_B_loss

                optim_G.step()
                
                cur_nimg += batch_size
                
                
                # ===report ===
                train_hist.add_params([G_gan_loss,G_idt_loss,G_recon_loss,d_loss_A,d_loss_B])
                if it% report_it == 0:                    
                    phase_time = time.time() - phase_start_time
                    losses = train_hist.check_current_avg()
                    it_time = time.time() - previous_time
                    vis.print_current_losses(cur_level, it, losses, it_time, phase_time)
                    vis.plot_current_losses(cur_level, float(i) / data_size, losses)
                    previous_time = time.time()
                # ===generate sample images===
                if it % show_it == 0:
                    save_result = it % save_it == 0
                    vis.display_current_results([real_A_cur,fake_B,recon_A],cur_level, it,save_result)
                    
                # ===save model===
                if it % save_it == 0:
                    save_models(all_models,project_dir)

    model_folder_at_scale = os.path.join(project_dir,str(R))
    if not os.path.isdir(model_folder_at_scale):
        os.makedirs(model_folder_at_scale)
    save_models(all_models,model_folder_at_scale)
# Out:
# stabilize phase, 4 resolution, 0 iteration upon 18750
# {'G_gan_loss': tensor(2.0849), 'G_idt_loss': tensor(0.0956), 'G_cycle_loss': tensor(0.7171), 'D_A_loss': tensor(0.6170), 'D_B_loss': tensor(0.6948)}
# stabilize phase, 4 resolution, 400 iteration upon 18750
# {'G_gan_loss': tensor(0.8257), 'G_idt_loss': tensor(0.1201), 'G_cycle_loss': tensor(0.5053), 'D_A_loss': tensor(0.3082), 'D_B_loss': tensor(0.2883)}
# stabilize phase, 4 resolution, 800 iteration upon 18750
# {'G_gan_loss': tensor(0.5718), 'G_idt_loss': tensor(0.1164), 'G_cycle_loss': tensor(0.5233), 'D_A_loss': tensor(0.2590), 'D_B_loss': tensor(0.2482)}
# stabilize phase, 4 resolution, 1200 iteration upon 18750
# {'G_gan_loss': tensor(0.5669), 'G_idt_loss': tensor(0.1173), 'G_cycle_loss': tensor(0.5214), 'D_A_loss': tensor(0.2566), 'D_B_loss': tensor(0.2456)}
# stabilize phase, 4 resolution, 1600 iteration upon 18750
# {'G_gan_loss': tensor(0.5717), 'G_idt_loss': tensor(0.1165), 'G_cycle_loss': tensor(0.5245), 'D_A_loss': tensor(0.2531), 'D_B_loss': tensor(0.2434)}
# stabilize phase, 4 resolution, 2000 iteration upon 18750
# {'G_gan_loss': tensor(0.5664), 'G_idt_loss': tensor(0.1169), 'G_cycle_loss': tensor(0.5240), 'D_A_loss': tensor(0.2549), 'D_B_loss': tensor(0.2433)}
# stabilize phase, 4 resolution, 2400 iteration upon 18750
# {'G_gan_loss': tensor(0.5700), 'G_idt_loss': tensor(0.1153), 'G_cycle_loss': tensor(0.5256), 'D_A_loss': tensor(0.2521), 'D_B_loss': tensor(0.2422)}
# stabilize phase, 4 resolution, 2800 iteration upon 18750
# {'G_gan_loss': tensor(0.5688), 'G_idt_loss': tensor(0.1165), 'G_cycle_loss': tensor(0.5274), 'D_A_loss': tensor(0.2506), 'D_B_loss': tensor(0.2438)}
# stabilize phase, 4 resolution, 3200 iteration upon 18750
# {'G_gan_loss': tensor(0.5738), 'G_idt_loss': tensor(0.1165), 'G_cycle_loss': tensor(0.5250), 'D_A_loss': tensor(0.2489), 'D_B_loss': tensor(0.2402)}
# stabilize phase, 4 resolution, 3600 iteration upon 18750
# {'G_gan_loss': tensor(0.5764), 'G_idt_loss': tensor(0.1162), 'G_cycle_loss': tensor(0.5278), 'D_A_loss': tensor(0.2469), 'D_B_loss': tensor(0.2406)}
# stabilize phase, 4 resolution, 4000 iteration upon 18750
# {'G_gan_loss': tensor(0.5830), 'G_idt_loss': tensor(0.1183), 'G_cycle_loss': tensor(0.5265), 'D_A_loss': tensor(0.2437), 'D_B_loss': tensor(0.2394)}
# stabilize phase, 4 resolution, 4400 iteration upon 18750
# {'G_gan_loss': tensor(0.5874), 'G_idt_loss': tensor(0.1185), 'G_cycle_loss': tensor(0.5329), 'D_A_loss': tensor(0.2418), 'D_B_loss': tensor(0.2393)}
# stabilize phase, 4 resolution, 4800 iteration upon 18750
# {'G_gan_loss': tensor(0.5961), 'G_idt_loss': tensor(0.1180), 'G_cycle_loss': tensor(0.5354), 'D_A_loss': tensor(0.2367), 'D_B_loss': tensor(0.2386)}
# stabilize phase, 4 resolution, 5200 iteration upon 18750
# {'G_gan_loss': tensor(0.6006), 'G_idt_loss': tensor(0.1203), 'G_cycle_loss': tensor(0.5386), 'D_A_loss': tensor(0.2346), 'D_B_loss': tensor(0.2385)}
# stabilize phase, 4 resolution, 5600 iteration upon 18750
# {'G_gan_loss': tensor(0.6127), 'G_idt_loss': tensor(0.1191), 'G_cycle_loss': tensor(0.5450), 'D_A_loss': tensor(0.2316), 'D_B_loss': tensor(0.2376)}
# stabilize phase, 4 resolution, 6000 iteration upon 18750
# {'G_gan_loss': tensor(0.6211), 'G_idt_loss': tensor(0.1202), 'G_cycle_loss': tensor(0.5474), 'D_A_loss': tensor(0.2267), 'D_B_loss': tensor(0.2358)}
# stabilize phase, 4 resolution, 6400 iteration upon 18750
# {'G_gan_loss': tensor(0.6318), 'G_idt_loss': tensor(0.1216), 'G_cycle_loss': tensor(0.5507), 'D_A_loss': tensor(0.2251), 'D_B_loss': tensor(0.2334)}
# stabilize phase, 4 resolution, 6800 iteration upon 18750
# {'G_gan_loss': tensor(0.6387), 'G_idt_loss': tensor(0.1201), 'G_cycle_loss': tensor(0.5533), 'D_A_loss': tensor(0.2206), 'D_B_loss': tensor(0.2348)}
# stabilize phase, 4 resolution, 7200 iteration upon 18750
# {'G_gan_loss': tensor(0.6478), 'G_idt_loss': tensor(0.1235), 'G_cycle_loss': tensor(0.5562), 'D_A_loss': tensor(0.2186), 'D_B_loss': tensor(0.2328)}
# stabilize phase, 4 resolution, 7600 iteration upon 18750
# {'G_gan_loss': tensor(0.6603), 'G_idt_loss': tensor(0.1193), 'G_cycle_loss': tensor(0.5706), 'D_A_loss': tensor(0.2144), 'D_B_loss': tensor(0.2329)}
# stabilize phase, 4 resolution, 8000 iteration upon 18750
# {'G_gan_loss': tensor(0.6618), 'G_idt_loss': tensor(0.1234), 'G_cycle_loss': tensor(0.5614), 'D_A_loss': tensor(0.2135), 'D_B_loss': tensor(0.2310)}
# stabilize phase, 4 resolution, 8400 iteration upon 18750
# {'G_gan_loss': tensor(0.6731), 'G_idt_loss': tensor(0.1230), 'G_cycle_loss': tensor(0.5665), 'D_A_loss': tensor(0.2118), 'D_B_loss': tensor(0.2302)}
# stabilize phase, 4 resolution, 8800 iteration upon 18750
# {'G_gan_loss': tensor(0.6791), 'G_idt_loss': tensor(0.1195), 'G_cycle_loss': tensor(0.5696), 'D_A_loss': tensor(0.2086), 'D_B_loss': tensor(0.2298)}
# stabilize phase, 4 resolution, 9200 iteration upon 18750
# {'G_gan_loss': tensor(0.6927), 'G_idt_loss': tensor(0.1218), 'G_cycle_loss': tensor(0.5684), 'D_A_loss': tensor(0.2062), 'D_B_loss': tensor(0.2267)}
# stabilize phase, 4 resolution, 9600 iteration upon 18750
# {'G_gan_loss': tensor(0.6967), 'G_idt_loss': tensor(0.1204), 'G_cycle_loss': tensor(0.5787), 'D_A_loss': tensor(0.2069), 'D_B_loss': tensor(0.2252)}
# stabilize phase, 4 resolution, 10000 iteration upon 18750
# {'G_gan_loss': tensor(0.6994), 'G_idt_loss': tensor(0.1248), 'G_cycle_loss': tensor(0.5655), 'D_A_loss': tensor(0.2051), 'D_B_loss': tensor(0.2255)}
# stabilize phase, 4 resolution, 10400 iteration upon 18750
# {'G_gan_loss': tensor(0.7211), 'G_idt_loss': tensor(0.1221), 'G_cycle_loss': tensor(0.5711), 'D_A_loss': tensor(0.2006), 'D_B_loss': tensor(0.2224)}
# stabilize phase, 4 resolution, 10800 iteration upon 18750
# {'G_gan_loss': tensor(0.7259), 'G_idt_loss': tensor(0.1231), 'G_cycle_loss': tensor(0.5773), 'D_A_loss': tensor(0.2005), 'D_B_loss': tensor(0.2212)}
# stabilize phase, 4 resolution, 11200 iteration upon 18750
# {'G_gan_loss': tensor(0.7324), 'G_idt_loss': tensor(0.1208), 'G_cycle_loss': tensor(0.5849), 'D_A_loss': tensor(0.1991), 'D_B_loss': tensor(0.2194)}
# stabilize phase, 4 resolution, 11600 iteration upon 18750
# {'G_gan_loss': tensor(0.7467), 'G_idt_loss': tensor(0.1260), 'G_cycle_loss': tensor(0.5640), 'D_A_loss': tensor(0.1933), 'D_B_loss': tensor(0.2160)}
# stabilize phase, 4 resolution, 12000 iteration upon 18750
# {'G_gan_loss': tensor(0.7516), 'G_idt_loss': tensor(0.1226), 'G_cycle_loss': tensor(0.6025), 'D_A_loss': tensor(0.1918), 'D_B_loss': tensor(0.2168)}
# stabilize phase, 4 resolution, 12400 iteration upon 18750
# {'G_gan_loss': tensor(0.7506), 'G_idt_loss': tensor(0.1229), 'G_cycle_loss': tensor(0.5766), 'D_A_loss': tensor(0.1927), 'D_B_loss': tensor(0.2172)}
# stabilize phase, 4 resolution, 12800 iteration upon 18750
# {'G_gan_loss': tensor(0.7567), 'G_idt_loss': tensor(0.1259), 'G_cycle_loss': tensor(0.5829), 'D_A_loss': tensor(0.1926), 'D_B_loss': tensor(0.2204)}
# stabilize phase, 4 resolution, 13200 iteration upon 18750
# {'G_gan_loss': tensor(0.7759), 'G_idt_loss': tensor(0.1218), 'G_cycle_loss': tensor(0.5887), 'D_A_loss': tensor(0.1893), 'D_B_loss': tensor(0.2124)}
# stabilize phase, 4 resolution, 13600 iteration upon 18750
# {'G_gan_loss': tensor(0.7792), 'G_idt_loss': tensor(0.1245), 'G_cycle_loss': tensor(0.5768), 'D_A_loss': tensor(0.1902), 'D_B_loss': tensor(0.2102)}
# stabilize phase, 4 resolution, 14000 iteration upon 18750
# {'G_gan_loss': tensor(0.7963), 'G_idt_loss': tensor(0.1228), 'G_cycle_loss': tensor(0.6070), 'D_A_loss': tensor(0.1838), 'D_B_loss': tensor(0.2130)}
# stabilize phase, 4 resolution, 14400 iteration upon 18750
# {'G_gan_loss': tensor(0.7793), 'G_idt_loss': tensor(0.1212), 'G_cycle_loss': tensor(0.5847), 'D_A_loss': tensor(0.1929), 'D_B_loss': tensor(0.2112)}
# stabilize phase, 4 resolution, 14800 iteration upon 18750
# {'G_gan_loss': tensor(0.7935), 'G_idt_loss': tensor(0.1259), 'G_cycle_loss': tensor(0.5864), 'D_A_loss': tensor(0.1916), 'D_B_loss': tensor(0.2088)}
# stabilize phase, 4 resolution, 15200 iteration upon 18750
# {'G_gan_loss': tensor(0.7897), 'G_idt_loss': tensor(0.1230), 'G_cycle_loss': tensor(0.6019), 'D_A_loss': tensor(0.1892), 'D_B_loss': tensor(0.2131)}
# stabilize phase, 4 resolution, 15600 iteration upon 18750
# {'G_gan_loss': tensor(0.8094), 'G_idt_loss': tensor(0.1231), 'G_cycle_loss': tensor(0.5899), 'D_A_loss': tensor(0.1856), 'D_B_loss': tensor(0.2095)}
# stabilize phase, 4 resolution, 16000 iteration upon 18750
# {'G_gan_loss': tensor(0.8084), 'G_idt_loss': tensor(0.1248), 'G_cycle_loss': tensor(0.5809), 'D_A_loss': tensor(0.1839), 'D_B_loss': tensor(0.2116)}
# stabilize phase, 4 resolution, 16400 iteration upon 18750
# {'G_gan_loss': tensor(0.8067), 'G_idt_loss': tensor(0.1258), 'G_cycle_loss': tensor(0.5850), 'D_A_loss': tensor(0.1892), 'D_B_loss': tensor(0.2113)}
# stabilize phase, 4 resolution, 16800 iteration upon 18750
# {'G_gan_loss': tensor(0.8109), 'G_idt_loss': tensor(0.1231), 'G_cycle_loss': tensor(0.5937), 'D_A_loss': tensor(0.1868), 'D_B_loss': tensor(0.2084)}
# stabilize phase, 4 resolution, 17200 iteration upon 18750
# {'G_gan_loss': tensor(0.8249), 'G_idt_loss': tensor(0.1215), 'G_cycle_loss': tensor(0.6029), 'D_A_loss': tensor(0.1879), 'D_B_loss': tensor(0.2104)}
# stabilize phase, 4 resolution, 17600 iteration upon 18750
# {'G_gan_loss': tensor(0.8282), 'G_idt_loss': tensor(0.1261), 'G_cycle_loss': tensor(0.5901), 'D_A_loss': tensor(0.1781), 'D_B_loss': tensor(0.2129)}
# stabilize phase, 4 resolution, 18000 iteration upon 18750
# {'G_gan_loss': tensor(0.8058), 'G_idt_loss': tensor(0.1231), 'G_cycle_loss': tensor(0.5878), 'D_A_loss': tensor(0.1898), 'D_B_loss': tensor(0.2152)}
# stabilize phase, 4 resolution, 18400 iteration upon 18750
# {'G_gan_loss': tensor(0.8319), 'G_idt_loss': tensor(0.1254), 'G_cycle_loss': tensor(0.6057), 'D_A_loss': tensor(0.1884), 'D_B_loss': tensor(0.2088)}
# /home/teejs/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/upsampling.py:129: UserWarning: nn.Upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.{} is deprecated. Use nn.functional.interpolate instead.".format(self.name))
# /home/teejs/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:2351: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# fade_in phase, 16 resolution, 18800 iteration upon 37500
# {'G_gan_loss': tensor(0.9441), 'G_idt_loss': tensor(0.1317), 'G_cycle_loss': tensor(0.6997), 'D_A_loss': tensor(0.1995), 'D_B_loss': tensor(0.2177)}
# fade_in phase, 16 resolution, 19200 iteration upon 37500
# {'G_gan_loss': tensor(1.4482), 'G_idt_loss': tensor(0.2108), 'G_cycle_loss': tensor(1.2014), 'D_A_loss': tensor(0.1695), 'D_B_loss': tensor(0.1380)}
# fade_in phase, 16 resolution, 19600 iteration upon 37500
# {'G_gan_loss': tensor(1.6664), 'G_idt_loss': tensor(0.1974), 'G_cycle_loss': tensor(1.1874), 'D_A_loss': tensor(0.1182), 'D_B_loss': tensor(0.0632)}
# fade_in phase, 16 resolution, 20000 iteration upon 37500
# {'G_gan_loss': tensor(1.9079), 'G_idt_loss': tensor(0.2060), 'G_cycle_loss': tensor(1.1563), 'D_A_loss': tensor(0.0714), 'D_B_loss': tensor(0.0236)}
# fade_in phase, 16 resolution, 20400 iteration upon 37500
# {'G_gan_loss': tensor(1.9954), 'G_idt_loss': tensor(0.2125), 'G_cycle_loss': tensor(1.1507), 'D_A_loss': tensor(0.0468), 'D_B_loss': tensor(0.0200)}
# fade_in phase, 16 resolution, 20800 iteration upon 37500
# {'G_gan_loss': tensor(2.0628), 'G_idt_loss': tensor(0.2066), 'G_cycle_loss': tensor(1.2284), 'D_A_loss': tensor(0.0295), 'D_B_loss': tensor(0.0189)}
# fade_in phase, 16 resolution, 21200 iteration upon 37500
# {'G_gan_loss': tensor(2.0861), 'G_idt_loss': tensor(0.1934), 'G_cycle_loss': tensor(1.2186), 'D_A_loss': tensor(0.0190), 'D_B_loss': tensor(0.0109)}
# fade_in phase, 16 resolution, 21600 iteration upon 37500
# {'G_gan_loss': tensor(2.0540), 'G_idt_loss': tensor(0.2198), 'G_cycle_loss': tensor(1.1606), 'D_A_loss': tensor(0.0140), 'D_B_loss': tensor(0.0074)}
# fade_in phase, 16 resolution, 22000 iteration upon 37500
# {'G_gan_loss': tensor(2.0483), 'G_idt_loss': tensor(0.2118), 'G_cycle_loss': tensor(1.1595), 'D_A_loss': tensor(0.0128), 'D_B_loss': tensor(0.0047)}
# fade_in phase, 16 resolution, 22400 iteration upon 37500
# {'G_gan_loss': tensor(2.0347), 'G_idt_loss': tensor(0.2103), 'G_cycle_loss': tensor(1.1231), 'D_A_loss': tensor(0.0092), 'D_B_loss': tensor(0.0044)}
# fade_in phase, 16 resolution, 22800 iteration upon 37500
# {'G_gan_loss': tensor(2.0200), 'G_idt_loss': tensor(0.1936), 'G_cycle_loss': tensor(0.9577), 'D_A_loss': tensor(0.0077), 'D_B_loss': tensor(0.0030)}
# fade_in phase, 16 resolution, 23200 iteration upon 37500
# {'G_gan_loss': tensor(2.0141), 'G_idt_loss': tensor(0.1829), 'G_cycle_loss': tensor(0.8585), 'D_A_loss': tensor(0.0059), 'D_B_loss': tensor(0.0031)}
# fade_in phase, 16 resolution, 23600 iteration upon 37500
# {'G_gan_loss': tensor(2.0304), 'G_idt_loss': tensor(0.1859), 'G_cycle_loss': tensor(0.9016), 'D_A_loss': tensor(0.0134), 'D_B_loss': tensor(0.0091)}
# fade_in phase, 16 resolution, 24000 iteration upon 37500
# {'G_gan_loss': tensor(2.0205), 'G_idt_loss': tensor(0.1739), 'G_cycle_loss': tensor(0.8983), 'D_A_loss': tensor(0.0058), 'D_B_loss': tensor(0.0035)}
# fade_in phase, 16 resolution, 24400 iteration upon 37500
# {'G_gan_loss': tensor(2.0107), 'G_idt_loss': tensor(0.1744), 'G_cycle_loss': tensor(0.8369), 'D_A_loss': tensor(0.0033), 'D_B_loss': tensor(0.0041)}
# fade_in phase, 16 resolution, 24800 iteration upon 37500
# {'G_gan_loss': tensor(2.0168), 'G_idt_loss': tensor(0.1561), 'G_cycle_loss': tensor(0.8293), 'D_A_loss': tensor(0.0033), 'D_B_loss': tensor(0.0066)}
# fade_in phase, 16 resolution, 25200 iteration upon 37500
# {'G_gan_loss': tensor(2.0133), 'G_idt_loss': tensor(0.1505), 'G_cycle_loss': tensor(0.7562), 'D_A_loss': tensor(0.0027), 'D_B_loss': tensor(0.0076)}
# fade_in phase, 16 resolution, 25600 iteration upon 37500
# {'G_gan_loss': tensor(2.0144), 'G_idt_loss': tensor(0.1512), 'G_cycle_loss': tensor(0.7474), 'D_A_loss': tensor(0.0070), 'D_B_loss': tensor(0.0075)}
# fade_in phase, 16 resolution, 26000 iteration upon 37500
# {'G_gan_loss': tensor(2.0162), 'G_idt_loss': tensor(0.1464), 'G_cycle_loss': tensor(0.8227), 'D_A_loss': tensor(0.0085), 'D_B_loss': tensor(0.0074)}
# fade_in phase, 16 resolution, 26400 iteration upon 37500
# {'G_gan_loss': tensor(2.0057), 'G_idt_loss': tensor(0.1465), 'G_cycle_loss': tensor(0.7059), 'D_A_loss': tensor(0.0029), 'D_B_loss': tensor(0.0059)}
# fade_in phase, 16 resolution, 26800 iteration upon 37500
# {'G_gan_loss': tensor(2.0053), 'G_idt_loss': tensor(0.1438), 'G_cycle_loss': tensor(0.6844), 'D_A_loss': tensor(0.0024), 'D_B_loss': tensor(0.0033)}
# fade_in phase, 16 resolution, 27200 iteration upon 37500
# {'G_gan_loss': tensor(2.0055), 'G_idt_loss': tensor(0.1453), 'G_cycle_loss': tensor(0.6873), 'D_A_loss': tensor(0.0034), 'D_B_loss': tensor(0.0043)}
# fade_in phase, 16 resolution, 27600 iteration upon 37500
# {'G_gan_loss': tensor(2.0037), 'G_idt_loss': tensor(0.1448), 'G_cycle_loss': tensor(0.6902), 'D_A_loss': tensor(0.0022), 'D_B_loss': tensor(0.0039)}
# fade_in phase, 16 resolution, 28000 iteration upon 37500
# {'G_gan_loss': tensor(2.0053), 'G_idt_loss': tensor(0.1424), 'G_cycle_loss': tensor(0.6776), 'D_A_loss': tensor(0.0020), 'D_B_loss': tensor(0.0027)}
# fade_in phase, 16 resolution, 28400 iteration upon 37500
# {'G_gan_loss': tensor(2.0043), 'G_idt_loss': tensor(0.1416), 'G_cycle_loss': tensor(0.6659), 'D_A_loss': tensor(0.0019), 'D_B_loss': tensor(0.0030)}
# fade_in phase, 16 resolution, 28800 iteration upon 37500
# {'G_gan_loss': tensor(2.0071), 'G_idt_loss': tensor(0.1378), 'G_cycle_loss': tensor(0.6802), 'D_A_loss': tensor(0.0030), 'D_B_loss': tensor(0.0015)}
# fade_in phase, 16 resolution, 29200 iteration upon 37500
# {'G_gan_loss': tensor(2.0024), 'G_idt_loss': tensor(0.1397), 'G_cycle_loss': tensor(0.6794), 'D_A_loss': tensor(0.0018), 'D_B_loss': tensor(0.0051)}
# fade_in phase, 16 resolution, 29600 iteration upon 37500
# {'G_gan_loss': tensor(2.0035), 'G_idt_loss': tensor(0.1401), 'G_cycle_loss': tensor(0.6621), 'D_A_loss': tensor(0.0018), 'D_B_loss': tensor(0.0044)}
# fade_in phase, 16 resolution, 30000 iteration upon 37500
# {'G_gan_loss': tensor(2.0042), 'G_idt_loss': tensor(0.1421), 'G_cycle_loss': tensor(0.6647), 'D_A_loss': tensor(0.0018), 'D_B_loss': tensor(0.0062)}
# fade_in phase, 16 resolution, 30400 iteration upon 37500
# {'G_gan_loss': tensor(2.0021), 'G_idt_loss': tensor(0.1410), 'G_cycle_loss': tensor(0.6575), 'D_A_loss': tensor(0.0016), 'D_B_loss': tensor(0.0024)}
# fade_in phase, 16 resolution, 30800 iteration upon 37500
# {'G_gan_loss': tensor(2.0039), 'G_idt_loss': tensor(0.1405), 'G_cycle_loss': tensor(0.6503), 'D_A_loss': tensor(0.0016), 'D_B_loss': tensor(0.0015)}
# fade_in phase, 16 resolution, 31200 iteration upon 37500
# {'G_gan_loss': tensor(2.0032), 'G_idt_loss': tensor(0.1404), 'G_cycle_loss': tensor(0.6420), 'D_A_loss': tensor(0.0015), 'D_B_loss': tensor(0.0014)}
# fade_in phase, 16 resolution, 31600 iteration upon 37500
# {'G_gan_loss': tensor(2.0067), 'G_idt_loss': tensor(0.1388), 'G_cycle_loss': tensor(0.6546), 'D_A_loss': tensor(0.0019), 'D_B_loss': tensor(0.0013)}
# fade_in phase, 16 resolution, 32000 iteration upon 37500
# {'G_gan_loss': tensor(2.0030), 'G_idt_loss': tensor(0.1399), 'G_cycle_loss': tensor(0.6458), 'D_A_loss': tensor(0.0015), 'D_B_loss': tensor(0.0012)}
# fade_in phase, 16 resolution, 32400 iteration upon 37500
# {'G_gan_loss': tensor(2.0028), 'G_idt_loss': tensor(0.1382), 'G_cycle_loss': tensor(0.6365), 'D_A_loss': tensor(0.0014), 'D_B_loss': tensor(0.0011)}
# fade_in phase, 16 resolution, 32800 iteration upon 37500
# {'G_gan_loss': tensor(2.0032), 'G_idt_loss': tensor(0.1391), 'G_cycle_loss': tensor(0.6351), 'D_A_loss': tensor(0.0014), 'D_B_loss': tensor(0.0011)}
# fade_in phase, 16 resolution, 33200 iteration upon 37500
# {'G_gan_loss': tensor(2.0027), 'G_idt_loss': tensor(0.1383), 'G_cycle_loss': tensor(0.6356), 'D_A_loss': tensor(0.0013), 'D_B_loss': tensor(0.0011)}
# fade_in phase, 16 resolution, 33600 iteration upon 37500
# {'G_gan_loss': tensor(2.0024), 'G_idt_loss': tensor(0.1392), 'G_cycle_loss': tensor(0.6431), 'D_A_loss': tensor(0.0013), 'D_B_loss': tensor(0.0036)}
# fade_in phase, 16 resolution, 34000 iteration upon 37500
# {'G_gan_loss': tensor(2.0026), 'G_idt_loss': tensor(0.1398), 'G_cycle_loss': tensor(0.6492), 'D_A_loss': tensor(0.0012), 'D_B_loss': tensor(0.0028)}
# fade_in phase, 16 resolution, 34400 iteration upon 37500
# {'G_gan_loss': tensor(2.0105), 'G_idt_loss': tensor(0.1381), 'G_cycle_loss': tensor(0.6505), 'D_A_loss': tensor(0.0035), 'D_B_loss': tensor(0.0010)}
# fade_in phase, 16 resolution, 34800 iteration upon 37500
# {'G_gan_loss': tensor(2.0020), 'G_idt_loss': tensor(0.1403), 'G_cycle_loss': tensor(0.6443), 'D_A_loss': tensor(0.0012), 'D_B_loss': tensor(0.0010)}
# fade_in phase, 16 resolution, 35200 iteration upon 37500
# {'G_gan_loss': tensor(2.0025), 'G_idt_loss': tensor(0.1380), 'G_cycle_loss': tensor(0.6397), 'D_A_loss': tensor(0.0012), 'D_B_loss': tensor(0.0010)}
# fade_in phase, 16 resolution, 35600 iteration upon 37500
# {'G_gan_loss': tensor(2.0023), 'G_idt_loss': tensor(0.1390), 'G_cycle_loss': tensor(0.6355), 'D_A_loss': tensor(0.0012), 'D_B_loss': tensor(0.0009)}
# fade_in phase, 16 resolution, 36000 iteration upon 37500
# {'G_gan_loss': tensor(2.0022), 'G_idt_loss': tensor(0.1383), 'G_cycle_loss': tensor(0.6333), 'D_A_loss': tensor(0.0011), 'D_B_loss': tensor(0.0009)}
# fade_in phase, 16 resolution, 36400 iteration upon 37500
# {'G_gan_loss': tensor(2.0022), 'G_idt_loss': tensor(0.1382), 'G_cycle_loss': tensor(0.6316), 'D_A_loss': tensor(0.0011), 'D_B_loss': tensor(0.0009)}
# fade_in phase, 16 resolution, 36800 iteration upon 37500
# {'G_gan_loss': tensor(2.0033), 'G_idt_loss': tensor(0.1387), 'G_cycle_loss': tensor(0.6372), 'D_A_loss': tensor(0.0011), 'D_B_loss': tensor(0.0012)}
# fade_in phase, 16 resolution, 37200 iteration upon 37500
# {'G_gan_loss': tensor(2.0025), 'G_idt_loss': tensor(0.1391), 'G_cycle_loss': tensor(0.6435), 'D_A_loss': tensor(0.0010), 'D_B_loss': tensor(0.0009)}
# stabilize phase, 8 resolution, 0 iteration upon 18750
# {'G_gan_loss': tensor(2.0004), 'G_idt_loss': tensor(0.1382), 'G_cycle_loss': tensor(0.6332), 'D_A_loss': tensor(0.0025), 'D_B_loss': tensor(0.0023)}
# stabilize phase, 8 resolution, 400 iteration upon 18750
# {'G_gan_loss': tensor(1.8716), 'G_idt_loss': tensor(0.1722), 'G_cycle_loss': tensor(1.2057), 'D_A_loss': tensor(0.0335), 'D_B_loss': tensor(0.0160)}
# stabilize phase, 8 resolution, 800 iteration upon 18750
# {'G_gan_loss': tensor(2.0128), 'G_idt_loss': tensor(0.1776), 'G_cycle_loss': tensor(1.2044), 'D_A_loss': tensor(0.0027), 'D_B_loss': tensor(0.0029)}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b19753e77a5c> in <module>
#      79
#      80                 recon_A = G_B(fake_B,cur_level=cur_level)
# ---> 81                 recon_A_loss = L1_loss(recon_A,real_A_cur) * lambda_recon
#      82
#      83                 G_A_loss = (d_fake_A_loss+sim_A_loss+recon_A_loss)*lambda_A
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#      91     @weak_script_method
#      92     def forward(self, input, target):
# ---> 93         return F.l1_loss(input, target, reduction=self.reduction)
#      94
#      95
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py in l1_loss(input, target, size_average, reduce, reduction)
#    2133     else:
#    2134         expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 2135         ret = torch._C._nn.l1_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#    2136     return ret
#    2137
#
# KeyboardInterrupt:
