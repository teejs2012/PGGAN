# %%
import torch,os
import torch.optim as optim
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
from utils.data import RandomNoiseGenerator,Data
from utils.train_history import train_history
import itertools
from models.model import Generator, Discriminator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')
if torch.backends.cudnn.enabled:
    torch.backends.cudnn.benchmark = True
device
# Out:
# device(type='cpu')

# %%
latent_size = 1024
target_resol = 256
first_resol = 4
use_sigmoid = False
train_kimg = 600000
transition_kimg = 600000

g_lr_max = 0.001
d_lr_max = 0.001

beta1 = 0
beta2 = 0.99

sample_freq = 100
save_freq = 100
report_freq = 100

lambda_A=10
lambda_B=10
lambda_recon=0.8
lambda_idt=0.1

# %%
result_dir = 'results'

# %%
real_dir = '/data/persona_cyclegan/real/'
anime_dir = '/data/persona_cyclegan/anime/'

data_A = Data(real_dir)
data_B = Data(anime_dir)
# Out:
# the folder does not exist
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d3013747db99> in <module>()
#       1 train_dir = '/data/persona_cyclegan/anime/trainB'
# ----> 2 data = Data(train_dir)
#
# ~\Documents\Dev\Persona\PGGAN\utils\data.py in __init__(self, folder)
#      57         if not os.path.isdir(folder):
#      58             print("the folder does not exist")
# ---> 59         self.files = os.listdir(self.datapath)
#      60         self.count = 0
#      61
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/data/persona_cyclegan/anime/trainB'

# %%
G_A = Generator(num_channels=3, latent_size=latent_size, resolution=target_resol, fmap_max=latent_size, fmap_base=8192, tanh_at_end=True)
G_B = Generator(num_channels=3, latent_size=latent_size, resolution=target_resol, fmap_max=latent_size, fmap_base=8192, tanh_at_end=True)

D_A = Discriminator(num_channels=3, mbstat_avg='all', resolution=target_resol, fmap_max=latent_size, fmap_base=8192, sigmoid_at_end=True)
D_B = Discriminator(num_channels=3, mbstat_avg='all', resolution=target_resol, fmap_max=latent_size, fmap_base=8192, sigmoid_at_end=True)

print(G)
print(D)
G_A,G_B,D_A,D_B = G_A.to(device),G_B.to(device),D_A.to(device),D_B.to(device)
optim_G = optim.Adam(itertools.chain(G_A.parameters(),G_B.parameters()), g_lr_max, betas=(beta1, beta2))
optim_D = optim.Adam(itertools.chain(D_A.parameters(),D_B.parameters()), d_lr_max, betas=(beta1, beta2))
# Out:
# C:\Users\teejs\Documents\Dev\Persona\PGGAN\models\model.py:323: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   kaiming_normal(layer.weight, a=gain)
# Generator(
#   (output_layer): GSelectLayer(
#     (pre): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#       (1): WScaleLayer(incoming = Conv2d)
#       (2): ReLU()
#       (3): PixelNormLayer(eps = 1e-08)
#       (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (5): WScaleLayer(incoming = Conv2d)
#       (6): ReLU()
#       (7): PixelNormLayer(eps = 1e-08)
#       (8): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (9): WScaleLayer(incoming = Conv2d)
#       (10): ReLU()
#       (11): PixelNormLayer(eps = 1e-08)
#       (12): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (13): WScaleLayer(incoming = Conv2d)
#       (14): ReLU()
#       (15): PixelNormLayer(eps = 1e-08)
#       (16): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (17): WScaleLayer(incoming = Conv2d)
#       (18): ReLU()
#       (19): PixelNormLayer(eps = 1e-08)
#       (20): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (21): WScaleLayer(incoming = Conv2d)
#       (22): ReLU()
#       (23): PixelNormLayer(eps = 1e-08)
#       (24): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (25): WScaleLayer(incoming = Conv2d)
#       (26): ReLU()
#       (27): PixelNormLayer(eps = 1e-08)
#       (28): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (29): WScaleLayer(incoming = Conv2d)
#       (30): ReLU()
#       (31): PixelNormLayer(eps = 1e-08)
#       (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (33): WScaleLayer(incoming = Conv2d)
#       (34): ReLU()
#       (35): PixelNormLayer(eps = 1e-08)
#       (36): Conv2d(512, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (37): WScaleLayer(incoming = Conv2d)
#       (38): ReLU()
#       (39): PixelNormLayer(eps = 1e-08)
#       (40): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (41): WScaleLayer(incoming = Conv2d)
#       (42): ReLU()
#       (43): PixelNormLayer(eps = 1e-08)
#       (44): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (45): WScaleLayer(incoming = Conv2d)
#       (46): ReLU()
#       (47): PixelNormLayer(eps = 1e-08)
#       (48): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (49): WScaleLayer(incoming = Conv2d)
#       (50): ReLU()
#       (51): PixelNormLayer(eps = 1e-08)
#       (52): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (53): WScaleLayer(incoming = Conv2d)
#       (54): ReLU()
#       (55): PixelNormLayer(eps = 1e-08)
#       (56): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (57): WScaleLayer(incoming = Conv2d)
#       (58): ReLU()
#       (59): PixelNormLayer(eps = 1e-08)
#       (60): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (61): WScaleLayer(incoming = Conv2d)
#       (62): ReLU()
#       (63): PixelNormLayer(eps = 1e-08)
#       (64): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (65): WScaleLayer(incoming = Conv2d)
#       (66): ReLU()
#       (67): PixelNormLayer(eps = 1e-08)
#     )
#     (chain): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1024, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(3, 3), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): ReLU()
#         (3): PixelNormLayer(eps = 1e-08)
#         (4): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (5): WScaleLayer(incoming = Conv2d)
#         (6): ReLU()
#         (7): PixelNormLayer(eps = 1e-08)
#       )
#       (1): Sequential(
#         (0): Upsample(scale_factor=2, mode=nearest)
#         (1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): ReLU()
#         (4): PixelNormLayer(eps = 1e-08)
#         (5): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): ReLU()
#         (8): PixelNormLayer(eps = 1e-08)
#       )
#       (2): Sequential(
#         (0): Upsample(scale_factor=2, mode=nearest)
#         (1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): ReLU()
#         (4): PixelNormLayer(eps = 1e-08)
#         (5): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): ReLU()
#         (8): PixelNormLayer(eps = 1e-08)
#       )
#       (3): Sequential(
#         (0): Upsample(scale_factor=2, mode=nearest)
#         (1): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): ReLU()
#         (4): PixelNormLayer(eps = 1e-08)
#         (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): ReLU()
#         (8): PixelNormLayer(eps = 1e-08)
#       )
#       (4): Sequential(
#         (0): Upsample(scale_factor=2, mode=nearest)
#         (1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): ReLU()
#         (4): PixelNormLayer(eps = 1e-08)
#         (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): ReLU()
#         (8): PixelNormLayer(eps = 1e-08)
#       )
#       (5): Sequential(
#         (0): Upsample(scale_factor=2, mode=nearest)
#         (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): ReLU()
#         (4): PixelNormLayer(eps = 1e-08)
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): ReLU()
#         (8): PixelNormLayer(eps = 1e-08)
#       )
#       (6): Sequential(
#         (0): Upsample(scale_factor=2, mode=nearest)
#         (1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): ReLU()
#         (4): PixelNormLayer(eps = 1e-08)
#         (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): ReLU()
#         (8): PixelNormLayer(eps = 1e-08)
#       )
#     )
#     (post): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1024, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): Tanh()
#       )
#       (1): Sequential(
#         (0): Conv2d(1024, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): Tanh()
#       )
#       (2): Sequential(
#         (0): Conv2d(1024, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): Tanh()
#       )
#       (3): Sequential(
#         (0): Conv2d(512, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): Tanh()
#       )
#       (4): Sequential(
#         (0): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): Tanh()
#       )
#       (5): Sequential(
#         (0): Conv2d(128, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): Tanh()
#       )
#       (6): Sequential(
#         (0): Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): Tanh()
#       )
#     )
#   )
# )
# Discriminator(
#   (output_layer): DSelectLayer(
#     (chain): ModuleList(
#       (0): Sequential(
#         (0): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): LeakyReLU(negative_slope=0.2)
#         (4): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): LeakyReLU(negative_slope=0.2)
#         (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (1): Sequential(
#         (0): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): LeakyReLU(negative_slope=0.2)
#         (4): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): LeakyReLU(negative_slope=0.2)
#         (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (2): Sequential(
#         (0): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): LeakyReLU(negative_slope=0.2)
#         (4): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (5): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): LeakyReLU(negative_slope=0.2)
#         (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (3): Sequential(
#         (0): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): LeakyReLU(negative_slope=0.2)
#         (4): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (5): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): LeakyReLU(negative_slope=0.2)
#         (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (4): Sequential(
#         (0): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): LeakyReLU(negative_slope=0.2)
#         (4): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (5): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): LeakyReLU(negative_slope=0.2)
#         (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (5): Sequential(
#         (0): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (2): WScaleLayer(incoming = Conv2d)
#         (3): LeakyReLU(negative_slope=0.2)
#         (4): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (5): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (6): WScaleLayer(incoming = Conv2d)
#         (7): LeakyReLU(negative_slope=0.2)
#         (8): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (6): Sequential(
#         (0): MinibatchStatConcatLayer(averaging = all)
#         (1): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (2): Conv2d(1025, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (3): WScaleLayer(incoming = Conv2d)
#         (4): LeakyReLU(negative_slope=0.2)
#         (5): GDropLayer(mode = prop, strength = 0.0, axes = [0, 1], normalize = False)
#         (6): Conv2d(1024, 1024, kernel_size=(4, 4), stride=(1, 1), bias=False)
#         (7): WScaleLayer(incoming = Conv2d)
#         (8): LeakyReLU(negative_slope=0.2)
#         (9): Conv2d(1024, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (10): WScaleLayer(incoming = Conv2d)
#         (11): Sigmoid()
#       )
#     )
#     (inputs): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): LeakyReLU(negative_slope=0.2)
#       )
#       (1): Sequential(
#         (0): Conv2d(3, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): LeakyReLU(negative_slope=0.2)
#       )
#       (2): Sequential(
#         (0): Conv2d(3, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): LeakyReLU(negative_slope=0.2)
#       )
#       (3): Sequential(
#         (0): Conv2d(3, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): LeakyReLU(negative_slope=0.2)
#       )
#       (4): Sequential(
#         (0): Conv2d(3, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): LeakyReLU(negative_slope=0.2)
#       )
#       (5): Sequential(
#         (0): Conv2d(3, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): LeakyReLU(negative_slope=0.2)
#       )
#       (6): Sequential(
#         (0): Conv2d(3, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): WScaleLayer(incoming = Conv2d)
#         (2): LeakyReLU(negative_slope=0.2)
#       )
#     )
#   )
# )

# %%
rampup_kimg = 10000
rampdown_kimg = 10000
total_kimg = 10000

def _rampup(epoch, rampup_length):
    if epoch < rampup_length:
        p = max(0.0, float(epoch)) / float(rampup_length)
        p = 1.0 - p
        return np.exp(-p*p*5.0)
    else:
        return 1.0

def _rampdown_linear(epoch, num_epochs, rampdown_length):
    if epoch >= num_epochs - rampdown_length:
        return float(num_epochs - epoch) / rampdown_length
    else:
        return 1.0

# %%
def get_bs(resolution):
    R = int(np.log2(resolution))
    if R < 7:
        bs = 32 / 2**(max(0, R-4))
    else:
        bs = 8 / 2**(min(2, R-7))
    return int(bs)

bs_map = {2**R: get_bs(2**R) for R in range(2, 11)}

# %%
train_hist = train_history(['G_loss','D_loss'])

# %%
L1_loss = nn.L1Loss().to(device)

# %% [markdown]
# ## Train

# %%
to_level = int(np.log2(target_resol))
from_level = int(np.log2(first_resol))

for R in range(from_level-1, to_level):
    batch_size = bs_map[2 ** (R+1)]
    phases = {'stabilize':[0, train_img//batch_size], 'fade_in':[train_img//batch_size+1, (transition_img+train_img)//batch_size]}

    for phase in ['stabilize', 'fade_in']:
        if phase in phases:
            _range = phases[phase]
            from_it = _range[0]
            total_it = _range[1]
            cur_nimg = _range[0]*batch_size
            resol = 2 ** (R+1)
            for it in range(from_it, total_it):
                if phase == 'stabilize':
                    cur_level = R
                else:
                    cur_level = R + total_it/float(from_it)
                cur_resol = 2 ** int(np.ceil(cur_level+1))

                # get a batch noise and real images
                real_A = data_A.next(batch_size,cur_resol,cur_level)
                real_A = real_A.to(device)
                
                real_B = data_B.next(batch_size,cur_resol,cur_level)
                real_B = real_B.to(device)
                # ===preprocess===
                for param_group in optim_G.param_groups:
                    lrate_coef = _rampup(cur_nimg / 1000.0, rampup_kimg)
                    lrate_coef *= _rampdown_linear(cur_nimg / 1000.0,total_kimg, rampdown_kimg)
                    param_group['lr'] = lrate_coef * g_lr_max
                for param_group in optim_D.param_groups:
                    lrate_coef = _rampup(cur_nimg / 1000.0, rampup_kimg)
                    lrate_coef *= _rampdown_linear(cur_nimg / 1000.0, total_kimg, rampdown_kimg)
                    param_group['lr'] = lrate_coef * d_lr_max

                # ===update D===
                for model in [D_A,D_B]:
                    for param in model.parameters():
                        param.requires_grad = True
                        
                optim_D.zero_grad()

                fake_B = G_A(real_A, cur_level=cur_level)
                d_real_B = D_B(real_B, cur_level=cur_level)
                d_fake_B = D_B(fake_B.detach(), cur_level=cur_level)

                d_real_B_loss = torch.mean((d_real_B-1)**2)
                d_fake_B_loss = torch.mean((d_fake_B-0)**2)
                 
                d_loss_B = 0.5 * (d_real_B_loss + d_fake_B_loss)
                d_loss_B.backward()
 
                fake_A = G_B(real_B, cur_level=cur_level)
                d_real_A = D_A(real_A, cur_level=cur_level)
                d_fake_A = D_A(fake_A.detach(), cur_level=cur_level)

                d_real_A_loss = torch.mean((d_real_A-1)**2)
                d_fake_A_loss = torch.mean((d_fake_A-0)**2)
                 
                d_loss_A = 0.5 * (d_real_A_loss + d_fake_A_loss)
                d_loss_A.backward()
                
                optim_D.step()

                # ===update G===
                for model in [D_A,D_B]:
                    for param in model.parameters():
                        param.requires_grad = False
                        
                optim_G.zero_grad()
                
                d_fake_A = D_B(fake_B, cur_level=cur_level)
                d_fake_A_loss = torch.mean((d_fake_A-1)**2)
                
                sim_A_loss = L1_loss(fake_B,real_A) * lambda_idt
                
                recon_A = G_B(fake_B,cur_level=cur_level)
                recon_A_loss = L1_loss(recon_A,real_A) * lambda_recon
                
                G_A_loss = (d_fake_A_loss+sim_A_loss+recon_A_loss)*lambda_A
                G_A_loss.backward()
                
                d_fake_B = D_A(fake_A,cur_level=cur_level)
                d_fake_B_loss = torch.mean((d_fake_B-1)**2)
                
                sim_B_loss = L1_loss(fake_A,real_B)*lambda_idt
                
                recon_B = G_A(fake_A,cur_level=cur_level)
                recon_B_loss = L1_loss(recon_B,real_B)*lambda_recon
                
                G_B_loss = (d_fake_B_loss + sim_B_loss + recon_B_loss)*lambda_B
                G_B_loss.backward()

                optim_G.step()
                
                cur_nimg += batch_size
                
#                 # ===report ===
#                 train_hist.add_params([g_loss,d_loss])
#                 if it% report_freq == 0:
#                     print('%s phase, %d resolution, %d iteration upon %d'%(phase, cur_resol, it, total_it))
#                     print(train_hist.check_current_avg())

#                 # ===generate sample images===
#                 samples = []
#                 if it % sample_freq == 0:
#                     img_to_save = (fake.detach()[0].cpu().numpy().transpose(1,2,0)+1)/2
#                     plt.imsave(os.path.join(result_dir, '%dx%d-%s-%s.png' % (cur_resol, cur_resol, phase, str(it).zfill(6))), img_to_save)

#                 # ===save model===
#                 if it % save_freq == 0:
#                     g_file = os.path.join(result_dir,'G.pth')
#                     d_file = os.path.join(result_dir,'D.pth')
#                     torch.save(G.state_dict(), g_file)
#                     torch.save(D.state_dict(), d_file)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-6b9c2d78680a> in <module>
#      42                 optim_D.zero_grad()
#      43
# ---> 44                 fake = G(z, cur_level=cur_level)
#      45                 d_real = D(real, cur_level=cur_level, gdrop_strength=0)
#      46                 d_fake = D(fake.detach(), cur_level=cur_level)
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/PGGAN/models/model.py in forward(self, x, y, cur_level, insert_y_at)
#     111
#     112     def forward(self, x, y=None, cur_level=None, insert_y_at=None):
# --> 113         return self.output_layer(x, y, cur_level, insert_y_at)
#     114
#     115
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/PGGAN/models/base_model.py in forward(self, x, y, cur_level, insert_y_at)
#     253                 x = self.chain[level](x, y)
#     254             else:
# --> 255                 x = self.chain[level](x)
#     256
#     257             if DEBUG:
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/PGGAN/models/base_model.py in forward(self, x)
#      46         x = self.scale * x
#      47         if self.bias is not None:
# ---> 48             x += self.bias.view(1, self.bias.size()[0], 1, 1)
#      49         return x
#      50
#
# RuntimeError: binary_op(): expected both inputs to be on same device, but input a is on cuda:0 and input b is on cuda:3
