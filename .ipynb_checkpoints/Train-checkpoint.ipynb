# %%
import torch,os,time
import torch.optim as optim
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
from utils.data import RandomNoiseGenerator,Data
from utils.train_history import train_history
from utils import visualizer,util
import itertools
from models.model import Generator, Discriminator
# from models.model import Generator_test, Discriminator_test
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')
if torch.backends.cudnn.enabled:
    torch.backends.cudnn.benchmark = True
device
# Out:
# device(type='cuda', index=3)

# %%
latent_size = 512
target_resol = 256
first_resol = 4
use_sigmoid = False
train_kimg = 600
train_img = train_kimg*1000
transition_kimg = 600
transition_img = transition_kimg*1000

g_lr_max =  0.002
d_lr_max =  0.002

beta1 = 0.5
beta2 = 0.999

lambda_A=10
lambda_B=10
lambda_recon=0.8
lambda_idt=0.1

report_it = 100
show_it = 100
save_it=100

# %%
display_id=1
display_winsize=256
display_ncols=4
display_server='http://localhost'
display_port=8097
display_env='pggan'
results_dir='results'
project_name = 'pggan1'
project_dir=os.path.join(results_dir,project_name)

vis = visualizer.Visualizer(display_id,display_winsize,display_ncols,display_server,display_port,display_env,
                 project_name,results_dir)

if not os.path.isdir(project_dir):
    os.makedirs(project_dir)
# Out:
# create web directory results/pggan1/web...

# %%
real_dir = '/data/persona_cyclegan/real/trainA'
anime_dir = '/data/persona_cyclegan/anime/trainB'
# real_dir = '/data/persona_cyclegan/real_test'
# anime_dir = '/data/persona_cyclegan/anime_test'
data_A = Data(real_dir)
data_B = Data(anime_dir)

# %%
G_A = Generator(num_channels=3, latent_size=latent_size, resolution=target_resol, fmap_max=latent_size, fmap_base=8192, tanh_at_end=True)
G_B = Generator(num_channels=3, latent_size=latent_size, resolution=target_resol, fmap_max=latent_size, fmap_base=8192, tanh_at_end=True)
# G_A = Generator_test()
# G_B = Generator_test()

D_A = Discriminator(num_channels=3, mbstat_avg='all', resolution=target_resol, fmap_max=latent_size, fmap_base=8192, sigmoid_at_end=True)
D_B = Discriminator(num_channels=3, mbstat_avg='all', resolution=target_resol, fmap_max=latent_size, fmap_base=8192, sigmoid_at_end=True)
# D_A = Discriminator_test()
# D_B = Discriminator_test()

print(G_A)
print(D_A)
G_A,G_B,D_A,D_B = G_A.to(device),G_B.to(device),D_A.to(device),D_B.to(device)
optim_G = optim.Adam(itertools.chain(G_A.parameters(),G_B.parameters()), g_lr_max, betas=(beta1, beta2))
optim_D_A = optim.Adam(D_A.parameters(), d_lr_max, betas=(beta1, beta2))
optim_D_B = optim.Adam(D_B.parameters(), d_lr_max, betas=(beta1, beta2))

all_models = {'G_A.pkl':G_A,
             'G_B.pkl':G_B,
             'D_A.pkl':D_A,
             'D_B.pkl':D_B}
            

print('---------- Networks initialized -------------')
for model_name,model in [('G',G_A),('D',D_A)]:
    num_params = 0
    for param in model.parameters():
        num_params += param.numel()
    print(str.format('{} has {} number of parameters', model_name, num_params))
print('-----------------------------------------------')
# Out:
# Generator(
#   (output_layer): GSelectLayer(
#     (pre): ModuleList(
#       (0): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (1): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (2): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (3): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (4): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 256, kernel_size=(7, 7), stride=(1, 1))
#         (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (5): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 128, kernel_size=(7, 7), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (6): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#         (2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#     )
#     (en_chain): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (1): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (2): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (3): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (5): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (6): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#     )
#     (de_chain): ModuleList(
#       (0): Sequential(
#         (0): ConvTranspose2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (1): Sequential(
#         (0): ConvTranspose2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (2): Sequential(
#         (0): ConvTranspose2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (3): Sequential(
#         (0): ConvTranspose2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (4): Sequential(
#         (0): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (5): Sequential(
#         (0): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (6): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#     )
#     (post): ModuleList(
#       (0): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(512, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (1): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(512, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (2): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(512, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (3): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(512, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (4): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(256, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (5): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(128, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (6): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#     )
#   )
# )
# Discriminator(
#   (output_layer): DSelectLayer(
#     (chain): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#         (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (1): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#         (3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (2): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#         (3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (3): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (4): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (5): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (6): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.2, inplace)
#         (6): Conv2d(512, 1, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (inputs): ModuleList(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (1): Conv2d(3, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (2): Conv2d(3, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (3): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (5): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (6): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     )
#   )
# )
# ---------- Networks initialized -------------
# G has 45463253 number of parameters
# D has 21583041 number of parameters
# -----------------------------------------------

# %%
rampup_kimg = 10000
rampdown_kimg = 10000
total_kimg = 10000

def _rampup(epoch, rampup_length):
    if epoch < rampup_length:
        p = max(0.0, float(epoch)) / float(rampup_length)
        p = 1.0 - p
        return np.exp(-p*p*5.0)
    else:
        return 1.0

def _rampdown_linear(epoch, num_epochs, rampdown_length):
    if epoch >= num_epochs - rampdown_length:
        return float(num_epochs - epoch) / rampdown_length
    else:
        return 1.0

# %%
def get_bs(resolution):
    R = int(np.log2(resolution))
    if R < 7:
        bs = 32 / 2**(max(0, R-4))
    else:
        bs = 8 / 2**(min(2, R-7))
    return int(bs)

bs_map = {2**R: get_bs(2**R) for R in range(2, 11)}

# %%
train_hist = train_history(['G_gan_loss',
                              'G_idt_loss',
                              'G_cycle_loss',
                              'D_A_real_loss',
                              'D_A_fake_loss',
                              'D_B_real_loss',                                         
                              'D_B_fake_loss',                                         
                              ])

# %%
L1_loss = nn.L1Loss().to(device) 
GAN_loss = nn.MSELoss().to(device)

# %%
def save_models(models, folder):
    for k, v in models.items():
        torch.save(v.state_dict(), os.path.join(folder, k))

# %% [markdown]
# ## Train

# %%
to_level = int(np.log2(target_resol))
from_level = int(np.log2(first_resol))

for R in range(from_level-1, to_level):
    batch_size = bs_map[2 ** (R+1)]
    phases = {'stabilize':[0, train_img//batch_size], 'fade_in':[train_img//batch_size+1, (transition_img+train_img)//batch_size]}
    if R==to_level-1:
        del phases['fade_in']
    print('starting scale %d, batch_size is %d, and the iterations in each phase is %d'%(R,batch_size,train_img//batch_size))
#     for phase in ['fade_in']: 
    for phase in ['stabilize', 'fade_in']:
        num_pool = 80
        fake_A_pool = util.ImagePool(num_pool)
        fake_B_pool = util.ImagePool(num_pool)
        if phase in phases:
            _range = phases[phase]
            from_it = _range[0]
            cur_it = 0
            total_it = _range[1]
            remaining_it = total_it-from_it
            cur_nimg = _range[0]*batch_size
            resol = 2 ** (R+1)
            
            previous_time = time.time()
            phase_start_time = time.time()
            
            for it in range(from_it, total_it):
                cur_it += 1
                if phase == 'stabilize':
                    cur_level = R
                else:
                    cur_level = R + cur_it/remaining_it
                cur_resol = 2 ** int(np.ceil(cur_level+1))

                # get a batch noise and real images
                real_A = data_A.next(batch_size,cur_resol,cur_level)
                real_A = real_A.to(device)
                
                real_B = data_B.next(batch_size,cur_resol,cur_level)
                real_B = real_B.to(device)
                # ===preprocess===
#                 for param_group in optim_G.param_groups:
#                     lrate_coef = _rampup(cur_nimg / 1000.0, rampup_kimg)
#                     lrate_coef *= _rampdown_linear(cur_nimg / 1000.0,total_kimg, rampdown_kimg)
#                     param_group['lr'] = lrate_coef * g_lr_max
  
#                 for param_group in optim_D_A.param_groups:
#                     lrate_coef = _rampup(cur_nimg / 1000.0, rampup_kimg)
#                     lrate_coef *= _rampdown_linear(cur_nimg / 1000.0, total_kimg, rampdown_kimg)
#                     param_group['lr'] = lrate_coef * d_lr_max
#                 for param_group in optim_D_B.param_groups:
#                     lrate_coef = _rampup(cur_nimg / 1000.0, rampup_kimg)
#                     lrate_coef *= _rampdown_linear(cur_nimg / 1000.0, total_kimg, rampdown_kimg)
#                     param_group['lr'] = lrate_coef * d_lr_max
                    
                
                # ===update G===
                for model in [D_A,D_B]:
                    for param in model.parameters():
                        param.requires_grad = False
                        
                optim_G.zero_grad()
                
                #G_A
                fake_B = G_A(real_A, cur_level)
                d_fake_A = D_B(fake_B, cur_level)
                d_fake_A_loss = GAN_loss(d_fake_A, torch.ones(d_fake_A.size(), device=device))
                
                sim_A_loss = L1_loss(fake_B,real_A) * lambda_idt
                
                recon_A = G_B(fake_B,cur_level)
                recon_A_loss = L1_loss(recon_A,real_A) * lambda_recon
                
                G_A_loss = (d_fake_A_loss+sim_A_loss+recon_A_loss)*lambda_A
                G_A_loss.backward()
                
                fake_A = G_B(real_B,cur_level)
                d_fake_B = D_A(fake_A,cur_level)
                d_fake_B_loss = GAN_loss(d_fake_B, torch.ones(d_fake_B.size(), device=device))

                sim_B_loss = L1_loss(fake_A,real_B)*lambda_idt
                
                recon_B = G_A(fake_A,cur_level)
                recon_B_loss = L1_loss(recon_B,real_B)*lambda_recon
                
                G_B_loss = (d_fake_B_loss + sim_B_loss + recon_B_loss)*lambda_B
                G_B_loss.backward()
                
                G_gan_loss = d_fake_A_loss + d_fake_B_loss
                G_idt_loss = sim_A_loss + sim_B_loss
                G_recon_loss = recon_A_loss + recon_B_loss

                optim_G.step()
 
#                 ===update D===
                for model in [D_A,D_B]:
                    for param in model.parameters():
                        param.requires_grad = True
                #D_B
                optim_D_B.zero_grad()

                fake_B = G_A(real_A, cur_level=cur_level)
                fake_B_from_pool = fake_B_pool.query(fake_B.detach())
                d_real_B = D_B(real_B, cur_level=cur_level)
                d_fake_B = D_B(fake_B_from_pool, cur_level=cur_level)

#                 d_real_B_loss = torch.mean((d_real_B-1)**2)
#                 d_fake_B_loss = torch.mean((d_fake_B-0)**2)
                d_real_B_loss = GAN_loss(d_real_B, torch.ones(d_real_B.size(), device=device))
                d_fake_B_loss = GAN_loss(d_fake_B, torch.zeros(d_fake_B.size(), device=device))
        
                d_loss_B = 0.5 * (d_real_B_loss + d_fake_B_loss)
                d_loss_B.backward()
                optim_D_B.step()
                
                #D_A
                optim_D_A.zero_grad()
 
                fake_A = G_B(real_B, cur_level=cur_level)
                fake_A_from_pool = fake_A_pool.query(fake_A.detach())
                d_real_A = D_A(real_A, cur_level=cur_level)
                d_fake_A = D_A(fake_A_from_pool, cur_level=cur_level)

#                 d_real_A_loss = torch.mean((d_real_A-1)**2)
#                 d_fake_A_loss = torch.mean((d_fake_A-0)**2)
                d_real_A_loss = GAN_loss(d_real_A, torch.ones(d_real_A.size(), device=device))
                d_fake_A_loss = GAN_loss(d_fake_A, torch.zeros(d_fake_A.size(), device=device))             
    
                d_loss_A = 0.5 * (d_real_A_loss + d_fake_A_loss)
                d_loss_A.backward()    
                optim_D_A.step()
                
                cur_nimg += batch_size
                
                cur_scale = R+cur_it/total_it/2
                if phase == 'fade_in':
                    cur_scale+=0.5
                
#                 if it%50 == 0:
#                     print('d_real_A_loss:%.3f,d_fake_A_loss:%.3f'%(d_real_A_loss,d_fake_A_loss))
#                     print(d_real_B)
#                     print(d_fake_B)

                # ===report ===
                train_hist.add_params([G_gan_loss,G_idt_loss,G_recon_loss,d_real_A_loss,d_fake_A_loss,d_real_B_loss,d_fake_B_loss])
                if it% report_it == 0:                    
                    phase_time = time.time() - phase_start_time
                    losses = train_hist.check_current_avg()
                    it_time = time.time() - previous_time
                    vis.print_current_losses(cur_level, it, losses, it_time, phase_time)
                    vis.plot_current_losses(cur_scale, losses)
                    previous_time = time.time()
                # ===generate sample images===
                if it % show_it == 0:
                    save_result = it % save_it == 0
                    vis.display_current_results([real_A,fake_B,recon_A],cur_scale,save_result)
                    
                # ===save model===
                if it % save_it == 0:
                    save_models(all_models,project_dir)
                    
#                 break

    model_folder_at_scale = os.path.join(project_dir,str(R))
    if not os.path.isdir(model_folder_at_scale):
        os.makedirs(model_folder_at_scale)
    save_models(all_models,model_folder_at_scale)
# Out:
# starting scale 1, batch_size is 32, and the iterations in each phase is 18750
# curlevel is 1.000
# torch.Size([32, 3, 4, 4])
# torch.Size([32, 1, 1, 1])
# curlevel is 1.000
# torch.Size([32, 3, 4, 4])
# torch.Size([32, 1, 1, 1])
# curlevel is 1.000
# torch.Size([32, 3, 4, 4])
# torch.Size([32, 1, 1, 1])
# curlevel is 1.000
# torch.Size([32, 3, 4, 4])
# torch.Size([32, 1, 1, 1])
# curlevel is 1.000
# torch.Size([32, 3, 4, 4])
# torch.Size([32, 1, 1, 1])
# curlevel is 1.000
# torch.Size([32, 3, 4, 4])
# torch.Size([32, 1, 1, 1])
# (current_level: 1.000, iters: 0, time_from_last_report: 0.683, since_the_phase_start: 0.680) G_gan_loss: 2.421 G_idt_loss: 0.178 G_cycle_loss: 1.261 D_A_real_loss: 1.262 D_A_fake_loss: 0.071 D_B_real_loss: 1.162 D_B_fake_loss: 0.055
# /home/teejs/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:2351: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# curlevel is 1.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# curlevel is 1.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# curlevel is 1.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# curlevel is 1.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# curlevel is 1.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# curlevel is 1.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# starting scale 2, batch_size is 32, and the iterations in each phase is 18750
# curlevel is 2.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# curlevel is 2.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# curlevel is 2.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# curlevel is 2.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# curlevel is 2.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# curlevel is 2.000
# torch.Size([32, 3, 8, 8])
# torch.Size([32, 1, 1, 1])
# (current_level: 2.000, iters: 0, time_from_last_report: 0.330, since_the_phase_start: 0.323) G_gan_loss: 3.576 G_idt_loss: 0.199 G_cycle_loss: 1.446 D_A_real_loss: 7.165 D_A_fake_loss: 0.304 D_B_real_loss: 2.304 D_B_fake_loss: 0.499
# curlevel is 2.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# curlevel is 2.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# curlevel is 2.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# curlevel is 2.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# curlevel is 2.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# curlevel is 2.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# starting scale 3, batch_size is 32, and the iterations in each phase is 18750
# curlevel is 3.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# curlevel is 3.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# curlevel is 3.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# curlevel is 3.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# curlevel is 3.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# curlevel is 3.000
# torch.Size([32, 3, 16, 16])
# torch.Size([32, 1, 1, 1])
# (current_level: 3.000, iters: 0, time_from_last_report: 0.520, since_the_phase_start: 0.505) G_gan_loss: 7.117 G_idt_loss: 0.190 G_cycle_loss: 1.607 D_A_real_loss: 5.517 D_A_fake_loss: 1.749 D_B_real_loss: 4.140 D_B_fake_loss: 1.807
# curlevel is 3.000
# torch.Size([32, 3, 32, 32])
# torch.Size([32, 1, 1, 1])
# curlevel is 3.000
# torch.Size([32, 3, 32, 32])
# torch.Size([32, 1, 1, 1])
# curlevel is 3.000
# torch.Size([32, 3, 32, 32])
# torch.Size([32, 1, 1, 1])
# curlevel is 3.000
# torch.Size([32, 3, 32, 32])
# torch.Size([32, 1, 1, 1])
# curlevel is 3.000
# torch.Size([32, 3, 32, 32])
# torch.Size([32, 1, 1, 1])
# curlevel is 3.000
# torch.Size([32, 3, 32, 32])
# torch.Size([32, 1, 1, 1])
# starting scale 4, batch_size is 16, and the iterations in each phase is 37500
# curlevel is 4.000
# torch.Size([16, 3, 32, 32])
# torch.Size([16, 1, 1, 1])
# curlevel is 4.000
# torch.Size([16, 3, 32, 32])
# torch.Size([16, 1, 1, 1])
# curlevel is 4.000
# torch.Size([16, 3, 32, 32])
# torch.Size([16, 1, 1, 1])
# curlevel is 4.000
# torch.Size([16, 3, 32, 32])
# torch.Size([16, 1, 1, 1])
# curlevel is 4.000
# torch.Size([16, 3, 32, 32])
# torch.Size([16, 1, 1, 1])
# curlevel is 4.000
# torch.Size([16, 3, 32, 32])
# torch.Size([16, 1, 1, 1])
# (current_level: 4.000, iters: 0, time_from_last_report: 2.656, since_the_phase_start: 2.628) G_gan_loss: 1.559 G_idt_loss: 0.166 G_cycle_loss: 1.474 D_A_real_loss: 1.037 D_A_fake_loss: 0.273 D_B_real_loss: 1.815 D_B_fake_loss: 0.646
# curlevel is 4.000
# torch.Size([16, 3, 64, 64])
# torch.Size([16, 1, 1, 1])
# curlevel is 4.000
# torch.Size([16, 3, 64, 64])
# torch.Size([16, 1, 1, 1])
# curlevel is 4.000
# torch.Size([16, 3, 64, 64])
# torch.Size([16, 1, 1, 1])
# curlevel is 4.000
# torch.Size([16, 3, 64, 64])
# torch.Size([16, 1, 1, 1])
# curlevel is 4.000
# torch.Size([16, 3, 64, 64])
# torch.Size([16, 1, 1, 1])
# curlevel is 4.000
# torch.Size([16, 3, 64, 64])
# torch.Size([16, 1, 1, 1])
# starting scale 5, batch_size is 8, and the iterations in each phase is 75000
# curlevel is 5.000
# torch.Size([8, 3, 64, 64])
# torch.Size([8, 1, 1, 1])
# curlevel is 5.000
# torch.Size([8, 3, 64, 64])
# torch.Size([8, 1, 1, 1])
# curlevel is 5.000
# torch.Size([8, 3, 64, 64])
# torch.Size([8, 1, 1, 1])
# curlevel is 5.000
# torch.Size([8, 3, 64, 64])
# torch.Size([8, 1, 1, 1])
# curlevel is 5.000
# torch.Size([8, 3, 64, 64])
# torch.Size([8, 1, 1, 1])
# curlevel is 5.000
# torch.Size([8, 3, 64, 64])
# torch.Size([8, 1, 1, 1])
# (current_level: 5.000, iters: 0, time_from_last_report: 4.079, since_the_phase_start: 4.049) G_gan_loss: 1.715 G_idt_loss: 0.182 G_cycle_loss: 1.449 D_A_real_loss: 0.321 D_A_fake_loss: 0.363 D_B_real_loss: 0.501 D_B_fake_loss: 0.331
# curlevel is 5.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# curlevel is 5.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# curlevel is 5.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# curlevel is 5.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# curlevel is 5.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# curlevel is 5.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# starting scale 6, batch_size is 8, and the iterations in each phase is 75000
# curlevel is 6.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# curlevel is 6.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# curlevel is 6.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# curlevel is 6.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# curlevel is 6.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# curlevel is 6.000
# torch.Size([8, 3, 128, 128])
# torch.Size([8, 1, 1, 1])
# (current_level: 6.000, iters: 0, time_from_last_report: 1.088, since_the_phase_start: 1.047) G_gan_loss: 0.861 G_idt_loss: 0.176 G_cycle_loss: 1.466 D_A_real_loss: 0.364 D_A_fake_loss: 0.306 D_B_real_loss: 0.426 D_B_fake_loss: 0.353
# curlevel is 6.000
# torch.Size([8, 3, 256, 256])
# torch.Size([8, 1, 1, 1])
# curlevel is 6.000
# torch.Size([8, 3, 256, 256])
# torch.Size([8, 1, 1, 1])
# curlevel is 6.000
# torch.Size([8, 3, 256, 256])
# torch.Size([8, 1, 1, 1])
# curlevel is 6.000
# torch.Size([8, 3, 256, 256])
# torch.Size([8, 1, 1, 1])
# curlevel is 6.000
# torch.Size([8, 3, 256, 256])
# torch.Size([8, 1, 1, 1])
# curlevel is 6.000
# torch.Size([8, 3, 256, 256])
# torch.Size([8, 1, 1, 1])
# starting scale 7, batch_size is 4, and the iterations in each phase is 150000
# curlevel is 7.000
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 1, 1, 1])
# curlevel is 7.000
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 1, 1, 1])
# curlevel is 7.000
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 1, 1, 1])
# curlevel is 7.000
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 1, 1, 1])
# curlevel is 7.000
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 1, 1, 1])
# curlevel is 7.000
# torch.Size([4, 3, 256, 256])
# torch.Size([4, 1, 1, 1])
# (current_level: 7.000, iters: 0, time_from_last_report: 3.899, since_the_phase_start: 3.865) G_gan_loss: 1.629 G_idt_loss: 0.164 G_cycle_loss: 1.243 D_A_real_loss: 0.315 D_A_fake_loss: 0.823 D_B_real_loss: 0.726 D_B_fake_loss: 0.840
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-20573f6ca20a> in <module>
#      61
#      62                 #G_A
# ---> 63                 fake_B = G_A(real_A, cur_level)
#      64                 d_fake_A = D_B(fake_B, cur_level)
#      65                 d_fake_A_loss = GAN_loss(d_fake_A, torch.ones(d_fake_A.size(), device=device))
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/PGGAN/models/model.py in forward(self, x, cur_level)
#     405
#     406     def forward(self, x, cur_level=None):
# --> 407         return self.output_layer(x, cur_level)
#     408
#     409 def init_weights(net, init_type='normal', gain=0.02):
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/PGGAN/models/model.py in forward(self, x, cur_level)
#     208         pooling = nn.AvgPool2d(2,stride=2)
#     209         if not min_level==max_level:
# --> 210             max_level_x = self.pre[max_level](x)
#     211             min_level_x = self.pre[min_level](pooling(x))
#     212             x = self.en_chain[max_level](max_level_x) * max_level_weight + min_level_x*min_level_weight
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/container.py in __getitem__(self, idx)
#     135             return self.__class__(list(self._modules.values())[idx])
#     136         else:
# --> 137             return self._modules[self._get_abs_string_index(idx)]
#     138
#     139     def __setitem__(self, idx, module):
#
# ~/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/container.py in _get_abs_string_index(self, idx)
#     126         idx = operator.index(idx)
#     127         if not (-len(self) <= idx < len(self)):
# --> 128             raise IndexError('index {} is out of range'.format(idx))
#     129         if idx < 0:
#     130             idx += len(self)
#
# IndexError: index 7 is out of range
