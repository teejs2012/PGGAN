# %%
import torch,os,time
import torch.optim as optim
import torch.nn as nn
from torch.autograd import Variable
from torchvision import transforms,datasets
import numpy as np
from utils.data import RandomNoiseGenerator,Data
from utils.train_history import train_history
from utils import visualizer,util
import itertools
from models.model import Generator, Discriminator
from IPython.core.debugger import set_trace
# from models.model import Generator_test, Discriminator_test
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
device = torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')
if torch.backends.cudnn.enabled:
    torch.backends.cudnn.benchmark = True
device
# Out:
# device(type='cuda', index=3)

# %%
latent_size = 512
target_resol = 256
first_resol = 4
use_sigmoid = False
train_kimg = 600
train_img = train_kimg*1000
transition_kimg = 600
transition_img = transition_kimg*1000

g_lr_max =  0.0002
d_lr_max =  0.0002

beta1 = 0.5
beta2 = 0.999

lambda_A=10
lambda_B=10
lambda_recon=2
lambda_idt=0.5

report_it = 400
show_it = 400
save_it=400

# %%
display_id=1
display_winsize=256
display_ncols=3
display_server='http://localhost'
display_port=8097
display_env='pggan'
results_dir='results'
project_name = 'pggan3'
project_dir=os.path.join(results_dir,project_name)

vis = visualizer.Visualizer(display_id,display_winsize,display_ncols,display_server,display_port,display_env,
                 project_name,results_dir)

if not os.path.isdir(project_dir):
    os.makedirs(project_dir)
# Out:
# create web directory results/pggan2/web...

# %%
real_dir = '/data/persona_cyclegan/faces_wo_bg/train'
# anime_dir = '/data/persona_cyclegan/anime_mix_face_3'
anime_dir = '/data/persona_cyclegan/anime_wo_bg/train'
# real_dir = '/data/persona_cyclegan/real_mix_face_2'

# real_dir = '/data/persona_cyclegan/real_test'
# anime_dir = '/data/persona_cyclegan/anime_test'
data_A = Data(real_dir)
data_B = Data(anime_dir)
print(data_A.get_count())
print(data_B.get_count())
# Out:
# 44476
# 38795

# %%
# real_dir = '/data/persona_cyclegan/faces_wo_bg'
# anime_dir = '/data/persona_cyclegan/anime'
# def load_imgs(src_data_path, tgt_data_path, fine_size):
# #     load_size = fine_size * 9//8
#     transform = transforms.Compose([
#             transforms.Resize((fine_size, fine_size)),
# #             transforms.RandomCrop(fine_size),
#             transforms.RandomHorizontalFlip(),
#             transforms.ColorJitter(0.1,0.1,0.1,0.1),
#             transforms.ToTensor(),
#             transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#     ])
    
#     train_loader_A = torch.utils.data.DataLoader(datasets.ImageFolder(src_data_path, transform), batch_size=32, shuffle=True, drop_last=True)
#     train_loader_B = torch.utils.data.DataLoader(datasets.ImageFolder(tgt_data_path, transform), batch_size=32, shuffle=True, drop_last=True)
#     return train_loader_A,train_loader_B

# train_loader_A,train_loader_B = load_imgs(real_dir, anime_dir, 8)

# %%
G_A = Generator(num_channels=3, latent_size=latent_size, resolution=target_resol, fmap_max=latent_size, fmap_base=8192, tanh_at_end=True,resnets=1)
G_B = Generator(num_channels=3, latent_size=latent_size, resolution=target_resol, fmap_max=latent_size, fmap_base=8192, tanh_at_end=True,resnets=1)
# G_A = Generator_test()
# G_B = Generator_test()

D_A = Discriminator(num_channels=3, mbstat_avg='all', resolution=target_resol, fmap_max=latent_size, fmap_base=8192, sigmoid_at_end=False)
D_B = Discriminator(num_channels=3, mbstat_avg='all', resolution=target_resol, fmap_max=latent_size, fmap_base=8192, sigmoid_at_end=False)
# D_A = Discriminator_test()
# D_B = Discriminator_test()

print(G_A)
print(D_A)
G_A,G_B,D_A,D_B = G_A.to(device),G_B.to(device),D_A.to(device),D_B.to(device)
optim_G = optim.Adam(itertools.chain(G_A.parameters(),G_B.parameters()), g_lr_max, betas=(beta1, beta2))
optim_D_A = optim.Adam(D_A.parameters(), d_lr_max, betas=(beta1, beta2))
optim_D_B = optim.Adam(D_B.parameters(), d_lr_max, betas=(beta1, beta2))

all_models = {'G_A.pkl':G_A,
             'G_B.pkl':G_B,
             'D_A.pkl':D_A,
             'D_B.pkl':D_B}
            

print('---------- Networks initialized -------------')
for model_name,model in [('G',G_A),('D',D_A)]:
    num_params = 0
    for param in model.parameters():
        num_params += param.numel()
    print(str.format('{} has {} number of parameters', model_name, num_params))
print('-----------------------------------------------')
# Out:
# Generator(
#   (output_layer): GSelectLayer(
#     (pre): ModuleList(
#       (0): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (1): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (2): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (3): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (4): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 256, kernel_size=(7, 7), stride=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (5): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 128, kernel_size=(7, 7), stride=(1, 1))
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (6): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#         (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#     )
#     (en_chain): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (1): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (2): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (3): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (4): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (5): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#       (6): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#       )
#     )
#     (de_chain): ModuleList(
#       (0): Sequential(
#         (0): ConvTranspose2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#         (4): resnet(
#           (conv_block): Sequential(
#             (0): ReflectionPad2d((1, 1, 1, 1))
#             (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#             (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (3): ReLU(inplace)
#             (4): ReflectionPad2d((1, 1, 1, 1))
#             (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#             (6): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#           )
#         )
#       )
#       (1): Sequential(
#         (0): ConvTranspose2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#         (4): resnet(
#           (conv_block): Sequential(
#             (0): ReflectionPad2d((1, 1, 1, 1))
#             (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#             (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (3): ReLU(inplace)
#             (4): ReflectionPad2d((1, 1, 1, 1))
#             (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#             (6): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#           )
#         )
#       )
#       (2): Sequential(
#         (0): ConvTranspose2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#         (4): resnet(
#           (conv_block): Sequential(
#             (0): ReflectionPad2d((1, 1, 1, 1))
#             (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#             (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (3): ReLU(inplace)
#             (4): ReflectionPad2d((1, 1, 1, 1))
#             (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#             (6): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#           )
#         )
#       )
#       (3): Sequential(
#         (0): ConvTranspose2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#         (4): resnet(
#           (conv_block): Sequential(
#             (0): ReflectionPad2d((1, 1, 1, 1))
#             (1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#             (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (3): ReLU(inplace)
#             (4): ReflectionPad2d((1, 1, 1, 1))
#             (5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#             (6): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#           )
#         )
#       )
#       (4): Sequential(
#         (0): ConvTranspose2d(512, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#         (4): resnet(
#           (conv_block): Sequential(
#             (0): ReflectionPad2d((1, 1, 1, 1))
#             (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#             (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (3): ReLU(inplace)
#             (4): ReflectionPad2d((1, 1, 1, 1))
#             (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1))
#             (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#           )
#         )
#       )
#       (5): Sequential(
#         (0): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#         (4): resnet(
#           (conv_block): Sequential(
#             (0): ReflectionPad2d((1, 1, 1, 1))
#             (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#             (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (3): ReLU(inplace)
#             (4): ReflectionPad2d((1, 1, 1, 1))
#             (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#             (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#           )
#         )
#       )
#       (6): Sequential(
#         (0): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#         (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace)
#         (4): resnet(
#           (conv_block): Sequential(
#             (0): ReflectionPad2d((1, 1, 1, 1))
#             (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#             (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (3): ReLU(inplace)
#             (4): ReflectionPad2d((1, 1, 1, 1))
#             (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#             (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#           )
#         )
#       )
#     )
#     (post): ModuleList(
#       (0): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(512, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (1): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(512, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (2): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(512, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (3): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(512, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (4): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(256, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (5): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(128, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#       (6): Sequential(
#         (0): ReflectionPad2d((3, 3, 3, 3))
#         (1): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1))
#         (2): Tanh()
#       )
#     )
#   )
# )
# Discriminator(
#   (output_layer): DSelectLayer(
#     (chain): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (1): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (3): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (4): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (5): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#       )
#       (6): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (2): LeakyReLU(negative_slope=0.2, inplace)
#         (3): Dropout(p=0.4)
#         (4): Conv2d(512, 1, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       )
#     )
#     (inputs): ModuleList(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (1): Conv2d(3, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (2): Conv2d(3, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (3): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (4): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (5): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#       (6): Conv2d(3, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     )
#   )
# )
# ---------- Networks initialized -------------
# G has 65890901 number of parameters
# D has 30900353 number of parameters
# -----------------------------------------------

# %%
rampup_kimg = 10000
rampdown_kimg = 10000
total_kimg = 10000

def _rampup(epoch, rampup_length):
    if epoch < rampup_length:
        p = max(0.0, float(epoch)) / float(rampup_length)
        p = 1.0 - p
        return np.exp(-p*p*5.0)
    else:
        return 1.0

def _rampdown_linear(epoch, num_epochs, rampdown_length):
    if epoch >= num_epochs - rampdown_length:
        return float(num_epochs - epoch) / rampdown_length
    else:
        return 1.0

# %%
def get_bs(resolution):
    R = int(np.log2(resolution))
    if R < 7:
        bs = 32 / 2**(max(0, R-4))
    else:
        bs = 8 / 2**(min(2, R-7))
    return int(bs)

bs_map = {2**R: get_bs(2**R) for R in range(2, 11)}

# %%
train_hist = train_history(['G_gan_loss',
                              'G_idt_loss',
                              'G_cycle_loss',
                              'D_A_real_loss',
                              'D_A_fake_loss',
                              'D_B_real_loss',                                         
                              'D_B_fake_loss',                                         
                              ])

# %%
L1_loss = nn.L1Loss().to(device) 
GAN_loss = nn.MSELoss().to(device)
# GAN_loss = nn.BCELoss().to(device)

# %%
def save_models(models, folder):
    for k, v in models.items():
        torch.save(v.state_dict(), os.path.join(folder, k))

# %% [markdown]
# ## Train

# %%
to_level = int(np.log2(target_resol))
from_level = int(np.log2(first_resol))

for model in [G_A,G_B,D_A,D_B]:
    model.train()

for R in range(from_level-1, to_level):
    batch_size = bs_map[2 ** (R+1)]
    phases = {'stabilize':[0, train_img//batch_size], 'fade_in':[train_img//batch_size+1, (transition_img+train_img)//batch_size]}
    if R==to_level-1:
        del phases['fade_in']
    print('starting scale %d, batch_size is %d, and the iterations in each phase is %d'%(R,batch_size,train_img//batch_size))
#     for phase in ['fade_in']: 
    for phase in ['stabilize', 'fade_in']:
        num_pool = 80
        fake_A_pool = util.ImagePool(num_pool)
        fake_B_pool = util.ImagePool(num_pool)
        if phase in phases:
            _range = phases[phase]
            from_it = _range[0]
            cur_it = 0
            total_it = _range[1]
            remaining_it = total_it-from_it
            cur_nimg = _range[0]*batch_size
            resol = 2 ** (R+1)
            
            previous_time = time.time()
            phase_start_time = time.time()
            
            for it in range(from_it, total_it):
#             print(len(train_loader_A))
#             print(len(train_loader_B))
#             for it,((real_A,_),(real_B,_)) in enumerate(zip(train_loader_A, train_loader_B)):
#                 set_trace()
                cur_it += 1
                if phase == 'stabilize':
                    cur_level = R
                else:
                    cur_level = R + cur_it/remaining_it
                cur_resol = 2 ** int(np.ceil(cur_level+1))
                cur_nimg += batch_size
                cur_scale = R+cur_it/total_it/2
                if phase == 'fade_in':
                    cur_scale+=0.5

                real_A = data_A.next(batch_size,cur_resol*2,cur_level+1)             
                real_B = data_B.next(batch_size,cur_resol*2,cur_level+1)
                real_A,real_B = real_A.to(device), real_B.to(device)
                # ===preprocess===
#                 for param_group in optim_G.param_groups:
#                     lrate_coef = _rampup(cur_nimg / 1000.0, rampup_kimg)
#                     lrate_coef *= _rampdown_linear(cur_nimg / 1000.0,total_kimg, rampdown_kimg)
#                     param_group['lr'] = lrate_coef * g_lr_max
  
#                 for param_group in optim_D_A.param_groups:
#                     lrate_coef = _rampup(cur_nimg / 1000.0, rampup_kimg)
#                     lrate_coef *= _rampdown_linear(cur_nimg / 1000.0, total_kimg, rampdown_kimg)
#                     param_group['lr'] = lrate_coef * d_lr_max
#                 for param_group in optim_D_B.param_groups:
#                     lrate_coef = _rampup(cur_nimg / 1000.0, rampup_kimg)
#                     lrate_coef *= _rampdown_linear(cur_nimg / 1000.0, total_kimg, rampdown_kimg)
#                     param_group['lr'] = lrate_coef * d_lr_max
                    
                
                # ===update G===
                for model in [D_A,D_B]:
                    for param in model.parameters():
                        param.requires_grad = False
                
                #G_A
                fake_B, G_model_status = G_A(real_A, cur_level)
                d_fake_A, D_model_status = D_B(fake_B, cur_level)
                d_fake_A_loss = GAN_loss(d_fake_A, torch.ones(d_fake_A.size(), device=device))
                
                sim_A_loss = L1_loss(fake_B,real_A) * lambda_idt
                
                recon_A,_ = G_B(fake_B,cur_level)
                recon_A_loss = L1_loss(recon_A,real_A) * lambda_recon
                
                G_A_loss = (d_fake_A_loss+sim_A_loss+recon_A_loss)*lambda_A
                
                
                fake_A,_ = G_B(real_B,cur_level)
                d_fake_B,_ = D_A(fake_A,cur_level)
                d_fake_B_loss = GAN_loss(d_fake_B, torch.ones(d_fake_B.size(), device=device))

                sim_B_loss = L1_loss(fake_A,real_B)*lambda_idt
                
                recon_B,_ = G_A(fake_A,cur_level)
                recon_B_loss = L1_loss(recon_B,real_B)*lambda_recon
                
                G_B_loss = (d_fake_B_loss + sim_B_loss + recon_B_loss)*lambda_B
                
                G_loss = G_A_loss+G_B_loss
                
                optim_G.zero_grad()
                G_loss.backward()
                optim_G.step()
                
                G_gan_loss = d_fake_A_loss + d_fake_B_loss
                G_idt_loss = sim_A_loss + sim_B_loss
                G_recon_loss = recon_A_loss + recon_B_loss

                # ===generate sample images===
                if it % show_it == 0:
                    save_result = it % save_it == 0
                    vis.display_current_results([real_A,fake_B,recon_A,real_B,fake_A,recon_B],cur_scale,save_result)
                    
#                 ===update D===
                
                for model in [D_A,D_B]:
                    for param in model.parameters():
                        param.requires_grad = True
                #D_B
                fake_B,_ = G_A(real_A, cur_level=cur_level)
                fake_B_from_pool = fake_B_pool.query(fake_B.detach())
                d_real_B,_ = D_B(real_B, cur_level=cur_level)
                d_fake_B,_ = D_B(fake_B_from_pool, cur_level=cur_level)

                d_real_B_loss = GAN_loss(d_real_B, torch.ones(d_real_B.size(), device=device))
                d_fake_B_loss = GAN_loss(d_fake_B, torch.zeros(d_fake_B.size(), device=device))
#                 d_real_B_loss = GAN_loss(d_real_B, 1-torch.rand(d_real_B.size(), device=device)/10.0)
#                 d_fake_B_loss = GAN_loss(d_fake_B, torch.rand(d_real_B.size(), device=device)/10.0)        

                d_loss_B = 0.5 * (d_real_B_loss + d_fake_B_loss)
                
                optim_D_B.zero_grad()
                d_loss_B.backward()
                optim_D_B.step()

                #D_A
                fake_A,_ = G_B(real_B, cur_level=cur_level)
                fake_A_from_pool = fake_A_pool.query(fake_A.detach())
                d_real_A,_ = D_A(real_A, cur_level=cur_level)
                d_fake_A,_ = D_A(fake_A_from_pool, cur_level=cur_level)

                d_real_A_loss = GAN_loss(d_real_A, torch.ones(d_real_A.size(), device=device))
                d_fake_A_loss = GAN_loss(d_fake_A, torch.zeros(d_fake_A.size(), device=device))             
#                 d_real_A_loss = GAN_loss(d_real_A, 1-torch.rand(d_real_B.size(), device=device)/10.0)
#                 d_fake_A_loss = GAN_loss(d_fake_A, torch.rand(d_real_B.size(), device=device)/10.0)      

                d_loss_A = 0.5 * (d_real_A_loss + d_fake_A_loss)
    
                optim_D_A.zero_grad()
                d_loss_A.backward()    
                optim_D_A.step()
            
            

                # ===report ===
                train_hist.add_params([G_gan_loss,G_idt_loss,G_recon_loss,d_real_A_loss,d_fake_A_loss,d_real_B_loss,d_fake_B_loss])
                if it% report_it == 0:                    
                    phase_time = time.time() - phase_start_time
                    losses = train_hist.check_current_avg()
                    it_time = time.time() - previous_time
                    vis.print_current_losses(cur_level, it, losses, it_time, phase_time)
                    vis.plot_current_losses(cur_scale, losses)
                    previous_time = time.time()
                    print(G_model_status)
                    print(D_model_status)
                    
                
                # ===save model===
                if it % save_it == 0:
                    save_models(all_models,project_dir)

    model_folder_at_scale = os.path.join(project_dir,str(R))
    if not os.path.isdir(model_folder_at_scale):
        os.makedirs(model_folder_at_scale)
    save_models(all_models,model_folder_at_scale)
# Out:
# starting scale 1, batch_size is 32, and the iterations in each phase is 18750
# (current_level: 1.000, iters: 0, time_from_last_report: 1.163, since_the_phase_start: 1.155) G_gan_loss: 6.834 G_idt_loss: 0.882 G_cycle_loss: 3.506 D_A_real_loss: 3.800 D_A_fake_loss: 4.823 D_B_real_loss: 2.904 D_B_fake_loss: 4.266
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 400, time_from_last_report: 163.020, since_the_phase_start: 163.955) G_gan_loss: 3.665 G_idt_loss: 0.899 G_cycle_loss: 2.686 D_A_real_loss: 1.189 D_A_fake_loss: 1.221 D_B_real_loss: 1.180 D_B_fake_loss: 1.260
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 800, time_from_last_report: 166.885, since_the_phase_start: 330.852) G_gan_loss: 2.126 G_idt_loss: 0.735 G_cycle_loss: 1.942 D_A_real_loss: 0.522 D_A_fake_loss: 0.558 D_B_real_loss: 0.512 D_B_fake_loss: 0.563
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 1200, time_from_last_report: 167.642, since_the_phase_start: 498.479) G_gan_loss: 1.466 G_idt_loss: 0.581 G_cycle_loss: 1.148 D_A_real_loss: 0.381 D_A_fake_loss: 0.383 D_B_real_loss: 0.328 D_B_fake_loss: 0.385
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 1600, time_from_last_report: 169.143, since_the_phase_start: 667.719) G_gan_loss: 1.146 G_idt_loss: 0.566 G_cycle_loss: 1.154 D_A_real_loss: 0.260 D_A_fake_loss: 0.281 D_B_real_loss: 0.290 D_B_fake_loss: 0.313
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 2000, time_from_last_report: 165.709, since_the_phase_start: 833.422) G_gan_loss: 1.154 G_idt_loss: 0.544 G_cycle_loss: 1.090 D_A_real_loss: 0.186 D_A_fake_loss: 0.226 D_B_real_loss: 0.231 D_B_fake_loss: 0.255
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 2400, time_from_last_report: 164.116, since_the_phase_start: 997.490) G_gan_loss: 1.102 G_idt_loss: 0.541 G_cycle_loss: 0.958 D_A_real_loss: 0.162 D_A_fake_loss: 0.195 D_B_real_loss: 0.225 D_B_fake_loss: 0.237
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 2800, time_from_last_report: 168.769, since_the_phase_start: 1166.254) G_gan_loss: 1.133 G_idt_loss: 0.546 G_cycle_loss: 1.029 D_A_real_loss: 0.137 D_A_fake_loss: 0.171 D_B_real_loss: 0.211 D_B_fake_loss: 0.224
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 3200, time_from_last_report: 166.702, since_the_phase_start: 1333.015) G_gan_loss: 1.102 G_idt_loss: 0.541 G_cycle_loss: 0.963 D_A_real_loss: 0.136 D_A_fake_loss: 0.163 D_B_real_loss: 0.204 D_B_fake_loss: 0.220
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 3600, time_from_last_report: 166.007, since_the_phase_start: 1499.056) G_gan_loss: 1.112 G_idt_loss: 0.537 G_cycle_loss: 0.884 D_A_real_loss: 0.128 D_A_fake_loss: 0.156 D_B_real_loss: 0.205 D_B_fake_loss: 0.217
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 4000, time_from_last_report: 169.127, since_the_phase_start: 1668.120) G_gan_loss: 1.187 G_idt_loss: 0.548 G_cycle_loss: 1.013 D_A_real_loss: 0.118 D_A_fake_loss: 0.154 D_B_real_loss: 0.188 D_B_fake_loss: 0.205
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 4400, time_from_last_report: 167.285, since_the_phase_start: 1835.381) G_gan_loss: 1.155 G_idt_loss: 0.537 G_cycle_loss: 0.903 D_A_real_loss: 0.137 D_A_fake_loss: 0.166 D_B_real_loss: 0.182 D_B_fake_loss: 0.203
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 4800, time_from_last_report: 165.865, since_the_phase_start: 2001.351) G_gan_loss: 1.116 G_idt_loss: 0.536 G_cycle_loss: 0.952 D_A_real_loss: 0.130 D_A_fake_loss: 0.168 D_B_real_loss: 0.202 D_B_fake_loss: 0.210
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 5200, time_from_last_report: 163.068, since_the_phase_start: 2164.437) G_gan_loss: 1.276 G_idt_loss: 0.619 G_cycle_loss: 1.270 D_A_real_loss: 0.574 D_A_fake_loss: 0.533 D_B_real_loss: 0.195 D_B_fake_loss: 0.201
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 5600, time_from_last_report: 168.399, since_the_phase_start: 2332.825) G_gan_loss: 1.000 G_idt_loss: 0.517 G_cycle_loss: 0.871 D_A_real_loss: 0.149 D_A_fake_loss: 0.173 D_B_real_loss: 0.200 D_B_fake_loss: 0.207
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 6000, time_from_last_report: 167.280, since_the_phase_start: 2500.105) G_gan_loss: 1.158 G_idt_loss: 0.546 G_cycle_loss: 0.930 D_A_real_loss: 0.082 D_A_fake_loss: 0.108 D_B_real_loss: 0.195 D_B_fake_loss: 0.203
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 6400, time_from_last_report: 166.709, since_the_phase_start: 2666.768) G_gan_loss: 1.219 G_idt_loss: 0.549 G_cycle_loss: 1.088 D_A_real_loss: 0.134 D_A_fake_loss: 0.165 D_B_real_loss: 0.150 D_B_fake_loss: 0.186
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 6800, time_from_last_report: 165.750, since_the_phase_start: 2832.553) G_gan_loss: 1.102 G_idt_loss: 0.530 G_cycle_loss: 0.956 D_A_real_loss: 0.136 D_A_fake_loss: 0.165 D_B_real_loss: 0.196 D_B_fake_loss: 0.203
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 7200, time_from_last_report: 167.999, since_the_phase_start: 3000.609) G_gan_loss: 1.052 G_idt_loss: 0.524 G_cycle_loss: 0.863 D_A_real_loss: 0.147 D_A_fake_loss: 0.181 D_B_real_loss: 0.199 D_B_fake_loss: 0.205
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 7600, time_from_last_report: 163.084, since_the_phase_start: 3163.666) G_gan_loss: 1.766 G_idt_loss: 0.731 G_cycle_loss: 1.675 D_A_real_loss: 0.132 D_A_fake_loss: 0.159 D_B_real_loss: 0.569 D_B_fake_loss: 0.483
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 8000, time_from_last_report: 164.811, since_the_phase_start: 3328.454) G_gan_loss: 1.620 G_idt_loss: 0.732 G_cycle_loss: 1.576 D_A_real_loss: 0.111 D_A_fake_loss: 0.147 D_B_real_loss: 0.074 D_B_fake_loss: 0.044
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 8400, time_from_last_report: 168.184, since_the_phase_start: 3496.659) G_gan_loss: 1.848 G_idt_loss: 0.744 G_cycle_loss: 1.497 D_A_real_loss: 0.066 D_A_fake_loss: 0.107 D_B_real_loss: 0.041 D_B_fake_loss: 0.026
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 8800, time_from_last_report: 166.619, since_the_phase_start: 3663.330) G_gan_loss: 1.845 G_idt_loss: 0.769 G_cycle_loss: 1.454 D_A_real_loss: 0.075 D_A_fake_loss: 0.113 D_B_real_loss: 0.031 D_B_fake_loss: 0.019
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 9200, time_from_last_report: 166.096, since_the_phase_start: 3829.485) G_gan_loss: 1.516 G_idt_loss: 0.750 G_cycle_loss: 1.474 D_A_real_loss: 0.357 D_A_fake_loss: 0.324 D_B_real_loss: 0.021 D_B_fake_loss: 0.013
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 9600, time_from_last_report: 164.837, since_the_phase_start: 3994.193) G_gan_loss: 0.972 G_idt_loss: 0.550 G_cycle_loss: 1.022 D_A_real_loss: 0.132 D_A_fake_loss: 0.153 D_B_real_loss: 0.198 D_B_fake_loss: 0.221
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 10000, time_from_last_report: 166.067, since_the_phase_start: 4160.363) G_gan_loss: 0.885 G_idt_loss: 0.527 G_cycle_loss: 0.910 D_A_real_loss: 0.164 D_A_fake_loss: 0.185 D_B_real_loss: 0.201 D_B_fake_loss: 0.209
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 10400, time_from_last_report: 165.230, since_the_phase_start: 4325.632) G_gan_loss: 0.935 G_idt_loss: 0.522 G_cycle_loss: 0.836 D_A_real_loss: 0.160 D_A_fake_loss: 0.180 D_B_real_loss: 0.205 D_B_fake_loss: 0.208
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 10800, time_from_last_report: 168.466, since_the_phase_start: 4494.090) G_gan_loss: 1.034 G_idt_loss: 0.535 G_cycle_loss: 0.905 D_A_real_loss: 0.151 D_A_fake_loss: 0.175 D_B_real_loss: 0.184 D_B_fake_loss: 0.199
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 11200, time_from_last_report: 168.353, since_the_phase_start: 4662.441) G_gan_loss: 1.276 G_idt_loss: 0.546 G_cycle_loss: 0.998 D_A_real_loss: 0.087 D_A_fake_loss: 0.121 D_B_real_loss: 0.189 D_B_fake_loss: 0.196
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 11600, time_from_last_report: 168.918, since_the_phase_start: 4831.421) G_gan_loss: 1.242 G_idt_loss: 0.544 G_cycle_loss: 1.019 D_A_real_loss: 0.093 D_A_fake_loss: 0.122 D_B_real_loss: 0.194 D_B_fake_loss: 0.198
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 12000, time_from_last_report: 170.010, since_the_phase_start: 5001.395) G_gan_loss: 1.406 G_idt_loss: 0.562 G_cycle_loss: 1.112 D_A_real_loss: 0.106 D_A_fake_loss: 0.139 D_B_real_loss: 0.133 D_B_fake_loss: 0.176
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 12400, time_from_last_report: 169.372, since_the_phase_start: 5170.843) G_gan_loss: 1.708 G_idt_loss: 0.556 G_cycle_loss: 1.139 D_A_real_loss: 0.048 D_A_fake_loss: 0.076 D_B_real_loss: 0.104 D_B_fake_loss: 0.141
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 12800, time_from_last_report: 166.279, since_the_phase_start: 5337.074) G_gan_loss: 1.320 G_idt_loss: 0.543 G_cycle_loss: 1.122 D_A_real_loss: 0.078 D_A_fake_loss: 0.117 D_B_real_loss: 0.176 D_B_fake_loss: 0.185
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 13200, time_from_last_report: 168.939, since_the_phase_start: 5505.987) G_gan_loss: 1.287 G_idt_loss: 0.518 G_cycle_loss: 0.884 D_A_real_loss: 0.079 D_A_fake_loss: 0.112 D_B_real_loss: 0.189 D_B_fake_loss: 0.191
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 13600, time_from_last_report: 166.255, since_the_phase_start: 5672.317) G_gan_loss: 1.294 G_idt_loss: 0.492 G_cycle_loss: 0.791 D_A_real_loss: 0.081 D_A_fake_loss: 0.115 D_B_real_loss: 0.201 D_B_fake_loss: 0.199
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 14000, time_from_last_report: 157.371, since_the_phase_start: 5829.758) G_gan_loss: 1.184 G_idt_loss: 0.500 G_cycle_loss: 0.747 D_A_real_loss: 0.104 D_A_fake_loss: 0.132 D_B_real_loss: 0.208 D_B_fake_loss: 0.207
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 14400, time_from_last_report: 135.800, since_the_phase_start: 5965.553) G_gan_loss: 1.183 G_idt_loss: 0.512 G_cycle_loss: 0.765 D_A_real_loss: 0.101 D_A_fake_loss: 0.144 D_B_real_loss: 0.207 D_B_fake_loss: 0.208
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 14800, time_from_last_report: 133.911, since_the_phase_start: 6099.477) G_gan_loss: 1.216 G_idt_loss: 0.503 G_cycle_loss: 0.752 D_A_real_loss: 0.088 D_A_fake_loss: 0.133 D_B_real_loss: 0.402 D_B_fake_loss: 0.374
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 15200, time_from_last_report: 135.223, since_the_phase_start: 6234.702) G_gan_loss: 0.955 G_idt_loss: 0.480 G_cycle_loss: 0.645 D_A_real_loss: 0.129 D_A_fake_loss: 0.166 D_B_real_loss: 0.261 D_B_fake_loss: 0.259
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 15600, time_from_last_report: 134.876, since_the_phase_start: 6369.594) G_gan_loss: 0.973 G_idt_loss: 0.501 G_cycle_loss: 0.690 D_A_real_loss: 0.114 D_A_fake_loss: 0.152 D_B_real_loss: 0.246 D_B_fake_loss: 0.248
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 16000, time_from_last_report: 134.436, since_the_phase_start: 6504.038) G_gan_loss: 1.124 G_idt_loss: 0.520 G_cycle_loss: 0.836 D_A_real_loss: 0.084 D_A_fake_loss: 0.129 D_B_real_loss: 0.220 D_B_fake_loss: 0.226
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 16400, time_from_last_report: 135.705, since_the_phase_start: 6639.717) G_gan_loss: 1.111 G_idt_loss: 0.496 G_cycle_loss: 0.698 D_A_real_loss: 0.098 D_A_fake_loss: 0.136 D_B_real_loss: 0.215 D_B_fake_loss: 0.219
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 16800, time_from_last_report: 134.070, since_the_phase_start: 6773.839) G_gan_loss: 1.206 G_idt_loss: 0.520 G_cycle_loss: 0.906 D_A_real_loss: 0.095 D_A_fake_loss: 0.135 D_B_real_loss: 0.196 D_B_fake_loss: 0.202
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 17200, time_from_last_report: 133.313, since_the_phase_start: 6907.165) G_gan_loss: 1.164 G_idt_loss: 0.526 G_cycle_loss: 0.910 D_A_real_loss: 0.109 D_A_fake_loss: 0.157 D_B_real_loss: 0.172 D_B_fake_loss: 0.185
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 17600, time_from_last_report: 133.439, since_the_phase_start: 7040.612) G_gan_loss: 1.083 G_idt_loss: 0.514 G_cycle_loss: 0.713 D_A_real_loss: 0.105 D_A_fake_loss: 0.151 D_B_real_loss: 0.206 D_B_fake_loss: 0.205
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 18000, time_from_last_report: 133.161, since_the_phase_start: 7173.777) G_gan_loss: 1.239 G_idt_loss: 0.538 G_cycle_loss: 0.775 D_A_real_loss: 0.082 D_A_fake_loss: 0.117 D_B_real_loss: 0.208 D_B_fake_loss: 0.207
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# (current_level: 1.000, iters: 18400, time_from_last_report: 135.128, since_the_phase_start: 7308.925) G_gan_loss: 1.418 G_idt_loss: 0.522 G_cycle_loss: 0.871 D_A_real_loss: 0.041 D_A_fake_loss: 0.079 D_B_real_loss: 0.201 D_B_fake_loss: 0.204
# {'pre_used': [0], 'enchain_used': [0], 'dechain_used': [0], 'post_used': [0]}
# {'inputs_used': [6], 'chain_used': [6]}
# /home/teejs/miniconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/functional.py:2351: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# (current_level: 1.003, iters: 18800, time_from_last_report: 32.177, since_the_phase_start: 31.993) G_gan_loss: 1.719 G_idt_loss: 0.514 G_cycle_loss: 1.655 D_A_real_loss: 0.571 D_A_fake_loss: 0.660 D_B_real_loss: 0.211 D_B_fake_loss: 0.212
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.024, iters: 19200, time_from_last_report: 255.751, since_the_phase_start: 287.684) G_gan_loss: 1.779 G_idt_loss: 0.588 G_cycle_loss: 2.595 D_A_real_loss: 0.038 D_A_fake_loss: 0.034 D_B_real_loss: 0.088 D_B_fake_loss: 0.078
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.045, iters: 19600, time_from_last_report: 257.180, since_the_phase_start: 544.860) G_gan_loss: 1.857 G_idt_loss: 0.700 G_cycle_loss: 2.048 D_A_real_loss: 0.039 D_A_fake_loss: 0.046 D_B_real_loss: 0.038 D_B_fake_loss: 0.031
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.067, iters: 20000, time_from_last_report: 257.898, since_the_phase_start: 802.767) G_gan_loss: 1.839 G_idt_loss: 0.791 G_cycle_loss: 2.203 D_A_real_loss: 0.053 D_A_fake_loss: 0.061 D_B_real_loss: 0.334 D_B_fake_loss: 0.385
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.088, iters: 20400, time_from_last_report: 257.878, since_the_phase_start: 1060.650) G_gan_loss: 1.319 G_idt_loss: 0.668 G_cycle_loss: 2.043 D_A_real_loss: 0.024 D_A_fake_loss: 0.033 D_B_real_loss: 0.249 D_B_fake_loss: 0.244
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.109, iters: 20800, time_from_last_report: 257.792, since_the_phase_start: 1318.469) G_gan_loss: 1.308 G_idt_loss: 0.630 G_cycle_loss: 1.605 D_A_real_loss: 0.046 D_A_fake_loss: 0.063 D_B_real_loss: 0.196 D_B_fake_loss: 0.192
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.131, iters: 21200, time_from_last_report: 257.166, since_the_phase_start: 1575.656) G_gan_loss: 1.628 G_idt_loss: 0.525 G_cycle_loss: 1.031 D_A_real_loss: 0.054 D_A_fake_loss: 0.072 D_B_real_loss: 0.109 D_B_fake_loss: 0.104
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.152, iters: 21600, time_from_last_report: 261.250, since_the_phase_start: 1836.918) G_gan_loss: 1.710 G_idt_loss: 0.507 G_cycle_loss: 0.970 D_A_real_loss: 0.031 D_A_fake_loss: 0.045 D_B_real_loss: 0.117 D_B_fake_loss: 0.107
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.173, iters: 22000, time_from_last_report: 256.543, since_the_phase_start: 2093.468) G_gan_loss: 1.641 G_idt_loss: 0.504 G_cycle_loss: 0.914 D_A_real_loss: 0.034 D_A_fake_loss: 0.048 D_B_real_loss: 0.135 D_B_fake_loss: 0.124
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.195, iters: 22400, time_from_last_report: 258.957, since_the_phase_start: 2352.402) G_gan_loss: 1.623 G_idt_loss: 0.481 G_cycle_loss: 0.866 D_A_real_loss: 0.022 D_A_fake_loss: 0.030 D_B_real_loss: 0.137 D_B_fake_loss: 0.133
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.216, iters: 22800, time_from_last_report: 258.704, since_the_phase_start: 2611.111) G_gan_loss: 1.538 G_idt_loss: 0.482 G_cycle_loss: 0.796 D_A_real_loss: 0.031 D_A_fake_loss: 0.039 D_B_real_loss: 0.147 D_B_fake_loss: 0.146
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.237, iters: 23200, time_from_last_report: 260.196, since_the_phase_start: 2871.321) G_gan_loss: 1.500 G_idt_loss: 0.471 G_cycle_loss: 0.757 D_A_real_loss: 0.038 D_A_fake_loss: 0.047 D_B_real_loss: 0.155 D_B_fake_loss: 0.157
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.259, iters: 23600, time_from_last_report: 259.673, since_the_phase_start: 3130.957) G_gan_loss: 1.432 G_idt_loss: 0.475 G_cycle_loss: 0.735 D_A_real_loss: 0.037 D_A_fake_loss: 0.043 D_B_real_loss: 0.164 D_B_fake_loss: 0.165
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.280, iters: 24000, time_from_last_report: 259.316, since_the_phase_start: 3390.321) G_gan_loss: 1.238 G_idt_loss: 0.460 G_cycle_loss: 0.721 D_A_real_loss: 0.038 D_A_fake_loss: 0.049 D_B_real_loss: 0.443 D_B_fake_loss: 0.382
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.301, iters: 24400, time_from_last_report: 259.650, since_the_phase_start: 3649.989) G_gan_loss: 1.027 G_idt_loss: 0.473 G_cycle_loss: 0.638 D_A_real_loss: 0.042 D_A_fake_loss: 0.052 D_B_real_loss: 0.258 D_B_fake_loss: 0.255
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.323, iters: 24800, time_from_last_report: 258.592, since_the_phase_start: 3908.585) G_gan_loss: 1.039 G_idt_loss: 0.472 G_cycle_loss: 0.608 D_A_real_loss: 0.045 D_A_fake_loss: 0.062 D_B_real_loss: 0.252 D_B_fake_loss: 0.250
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.344, iters: 25200, time_from_last_report: 258.072, since_the_phase_start: 4166.699) G_gan_loss: 0.979 G_idt_loss: 0.478 G_cycle_loss: 0.765 D_A_real_loss: 0.299 D_A_fake_loss: 0.270 D_B_real_loss: 0.248 D_B_fake_loss: 0.245
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.365, iters: 25600, time_from_last_report: 257.591, since_the_phase_start: 4424.311) G_gan_loss: 0.927 G_idt_loss: 0.482 G_cycle_loss: 0.621 D_A_real_loss: 0.092 D_A_fake_loss: 0.110 D_B_real_loss: 0.248 D_B_fake_loss: 0.246
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.387, iters: 26000, time_from_last_report: 257.067, since_the_phase_start: 4681.364) G_gan_loss: 0.931 G_idt_loss: 0.482 G_cycle_loss: 0.627 D_A_real_loss: 0.043 D_A_fake_loss: 0.060 D_B_real_loss: 0.240 D_B_fake_loss: 0.239
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.408, iters: 26400, time_from_last_report: 258.847, since_the_phase_start: 4940.216) G_gan_loss: 1.123 G_idt_loss: 0.486 G_cycle_loss: 0.685 D_A_real_loss: 0.030 D_A_fake_loss: 0.040 D_B_real_loss: 0.270 D_B_fake_loss: 0.262
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.429, iters: 26800, time_from_last_report: 261.582, since_the_phase_start: 5201.796) G_gan_loss: 0.846 G_idt_loss: 0.480 G_cycle_loss: 0.784 D_A_real_loss: 0.189 D_A_fake_loss: 0.184 D_B_real_loss: 0.209 D_B_fake_loss: 0.209
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.451, iters: 27200, time_from_last_report: 260.689, since_the_phase_start: 5462.512) G_gan_loss: 1.174 G_idt_loss: 0.498 G_cycle_loss: 0.697 D_A_real_loss: 0.037 D_A_fake_loss: 0.049 D_B_real_loss: 0.179 D_B_fake_loss: 0.183
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.472, iters: 27600, time_from_last_report: 259.023, since_the_phase_start: 5721.563) G_gan_loss: 1.533 G_idt_loss: 0.511 G_cycle_loss: 1.091 D_A_real_loss: 0.033 D_A_fake_loss: 0.044 D_B_real_loss: 0.062 D_B_fake_loss: 0.064
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.493, iters: 28000, time_from_last_report: 258.159, since_the_phase_start: 5979.732) G_gan_loss: 1.520 G_idt_loss: 0.530 G_cycle_loss: 1.160 D_A_real_loss: 0.037 D_A_fake_loss: 0.044 D_B_real_loss: 0.080 D_B_fake_loss: 0.094
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.515, iters: 28400, time_from_last_report: 256.840, since_the_phase_start: 6236.585) G_gan_loss: 1.250 G_idt_loss: 0.491 G_cycle_loss: 0.918 D_A_real_loss: 0.033 D_A_fake_loss: 0.041 D_B_real_loss: 0.263 D_B_fake_loss: 0.238
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.536, iters: 28800, time_from_last_report: 257.426, since_the_phase_start: 6494.008) G_gan_loss: 1.189 G_idt_loss: 0.484 G_cycle_loss: 0.829 D_A_real_loss: 0.047 D_A_fake_loss: 0.053 D_B_real_loss: 0.173 D_B_fake_loss: 0.174
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.557, iters: 29200, time_from_last_report: 262.583, since_the_phase_start: 6756.565) G_gan_loss: 1.305 G_idt_loss: 0.484 G_cycle_loss: 0.844 D_A_real_loss: 0.038 D_A_fake_loss: 0.049 D_B_real_loss: 0.138 D_B_fake_loss: 0.147
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.579, iters: 29600, time_from_last_report: 264.663, since_the_phase_start: 7021.273) G_gan_loss: 1.254 G_idt_loss: 0.504 G_cycle_loss: 0.875 D_A_real_loss: 0.053 D_A_fake_loss: 0.061 D_B_real_loss: 0.120 D_B_fake_loss: 0.129
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.600, iters: 30000, time_from_last_report: 259.820, since_the_phase_start: 7281.083) G_gan_loss: 1.102 G_idt_loss: 0.509 G_cycle_loss: 0.927 D_A_real_loss: 0.260 D_A_fake_loss: 0.238 D_B_real_loss: 0.098 D_B_fake_loss: 0.104
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.621, iters: 30400, time_from_last_report: 259.421, since_the_phase_start: 7540.556) G_gan_loss: 1.231 G_idt_loss: 0.517 G_cycle_loss: 0.950 D_A_real_loss: 0.071 D_A_fake_loss: 0.090 D_B_real_loss: 0.124 D_B_fake_loss: 0.135
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.643, iters: 30800, time_from_last_report: 258.498, since_the_phase_start: 7799.084) G_gan_loss: 1.348 G_idt_loss: 0.509 G_cycle_loss: 0.936 D_A_real_loss: 0.071 D_A_fake_loss: 0.082 D_B_real_loss: 0.176 D_B_fake_loss: 0.178
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.664, iters: 31200, time_from_last_report: 257.505, since_the_phase_start: 8056.601) G_gan_loss: 1.213 G_idt_loss: 0.498 G_cycle_loss: 0.785 D_A_real_loss: 0.053 D_A_fake_loss: 0.076 D_B_real_loss: 0.190 D_B_fake_loss: 0.187
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.685, iters: 31600, time_from_last_report: 259.996, since_the_phase_start: 8316.580) G_gan_loss: 1.312 G_idt_loss: 0.517 G_cycle_loss: 0.862 D_A_real_loss: 0.033 D_A_fake_loss: 0.047 D_B_real_loss: 0.182 D_B_fake_loss: 0.178
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.707, iters: 32000, time_from_last_report: 262.888, since_the_phase_start: 8579.484) G_gan_loss: 1.437 G_idt_loss: 0.518 G_cycle_loss: 0.974 D_A_real_loss: 0.035 D_A_fake_loss: 0.045 D_B_real_loss: 0.170 D_B_fake_loss: 0.164
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.728, iters: 32400, time_from_last_report: 261.310, since_the_phase_start: 8840.807) G_gan_loss: 1.447 G_idt_loss: 0.533 G_cycle_loss: 1.085 D_A_real_loss: 0.053 D_A_fake_loss: 0.068 D_B_real_loss: 0.175 D_B_fake_loss: 0.169
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.749, iters: 32800, time_from_last_report: 257.842, since_the_phase_start: 9098.655) G_gan_loss: 1.559 G_idt_loss: 0.518 G_cycle_loss: 1.046 D_A_real_loss: 0.042 D_A_fake_loss: 0.058 D_B_real_loss: 0.150 D_B_fake_loss: 0.146
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.771, iters: 33200, time_from_last_report: 258.457, since_the_phase_start: 9357.163) G_gan_loss: 1.472 G_idt_loss: 0.506 G_cycle_loss: 0.992 D_A_real_loss: 0.052 D_A_fake_loss: 0.071 D_B_real_loss: 0.168 D_B_fake_loss: 0.161
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.792, iters: 33600, time_from_last_report: 258.106, since_the_phase_start: 9615.268) G_gan_loss: 1.292 G_idt_loss: 0.529 G_cycle_loss: 1.181 D_A_real_loss: 0.074 D_A_fake_loss: 0.092 D_B_real_loss: 0.164 D_B_fake_loss: 0.156
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.813, iters: 34000, time_from_last_report: 259.291, since_the_phase_start: 9874.567) G_gan_loss: 1.256 G_idt_loss: 0.516 G_cycle_loss: 1.024 D_A_real_loss: 0.107 D_A_fake_loss: 0.121 D_B_real_loss: 0.182 D_B_fake_loss: 0.171
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.835, iters: 34400, time_from_last_report: 256.719, since_the_phase_start: 10131.312) G_gan_loss: 1.253 G_idt_loss: 0.510 G_cycle_loss: 0.997 D_A_real_loss: 0.114 D_A_fake_loss: 0.128 D_B_real_loss: 0.188 D_B_fake_loss: 0.178
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.856, iters: 34800, time_from_last_report: 257.274, since_the_phase_start: 10388.603) G_gan_loss: 1.140 G_idt_loss: 0.516 G_cycle_loss: 0.968 D_A_real_loss: 0.148 D_A_fake_loss: 0.157 D_B_real_loss: 0.192 D_B_fake_loss: 0.184
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.877, iters: 35200, time_from_last_report: 260.528, since_the_phase_start: 10649.124) G_gan_loss: 1.039 G_idt_loss: 0.517 G_cycle_loss: 0.941 D_A_real_loss: 0.166 D_A_fake_loss: 0.161 D_B_real_loss: 0.199 D_B_fake_loss: 0.190
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.899, iters: 35600, time_from_last_report: 259.325, since_the_phase_start: 10908.455) G_gan_loss: 1.185 G_idt_loss: 0.517 G_cycle_loss: 0.996 D_A_real_loss: 0.143 D_A_fake_loss: 0.160 D_B_real_loss: 0.187 D_B_fake_loss: 0.180
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.920, iters: 36000, time_from_last_report: 259.662, since_the_phase_start: 11168.116) G_gan_loss: 0.989 G_idt_loss: 0.517 G_cycle_loss: 0.943 D_A_real_loss: 0.184 D_A_fake_loss: 0.183 D_B_real_loss: 0.195 D_B_fake_loss: 0.186
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.941, iters: 36400, time_from_last_report: 258.945, since_the_phase_start: 11427.099) G_gan_loss: 0.961 G_idt_loss: 0.522 G_cycle_loss: 0.937 D_A_real_loss: 0.180 D_A_fake_loss: 0.179 D_B_real_loss: 0.206 D_B_fake_loss: 0.199
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.963, iters: 36800, time_from_last_report: 260.419, since_the_phase_start: 11687.500) G_gan_loss: 1.256 G_idt_loss: 0.552 G_cycle_loss: 1.203 D_A_real_loss: 0.101 D_A_fake_loss: 0.113 D_B_real_loss: 0.193 D_B_fake_loss: 0.185
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 1.984, iters: 37200, time_from_last_report: 262.853, since_the_phase_start: 11950.376) G_gan_loss: 1.365 G_idt_loss: 0.540 G_cycle_loss: 1.068 D_A_real_loss: 0.064 D_A_fake_loss: 0.086 D_B_real_loss: 0.190 D_B_fake_loss: 0.184
# {'pre_used': [1, 1, 0], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [0, 1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# starting scale 2, batch_size is 32, and the iterations in each phase is 18750
# (current_level: 2.000, iters: 0, time_from_last_report: 0.798, since_the_phase_start: 0.581) G_gan_loss: 1.298 G_idt_loss: 0.520 G_cycle_loss: 0.982 D_A_real_loss: 0.071 D_A_fake_loss: 0.100 D_B_real_loss: 0.203 D_B_fake_loss: 0.197
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 400, time_from_last_report: 238.352, since_the_phase_start: 238.934) G_gan_loss: 1.348 G_idt_loss: 0.538 G_cycle_loss: 1.059 D_A_real_loss: 0.057 D_A_fake_loss: 0.074 D_B_real_loss: 0.207 D_B_fake_loss: 0.200
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 800, time_from_last_report: 234.365, since_the_phase_start: 473.327) G_gan_loss: 1.099 G_idt_loss: 0.541 G_cycle_loss: 1.043 D_A_real_loss: 0.132 D_A_fake_loss: 0.142 D_B_real_loss: 0.205 D_B_fake_loss: 0.200
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 1200, time_from_last_report: 234.406, since_the_phase_start: 707.749) G_gan_loss: 1.033 G_idt_loss: 0.550 G_cycle_loss: 1.011 D_A_real_loss: 0.126 D_A_fake_loss: 0.142 D_B_real_loss: 0.211 D_B_fake_loss: 0.206
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 1600, time_from_last_report: 235.617, since_the_phase_start: 943.370) G_gan_loss: 0.954 G_idt_loss: 0.533 G_cycle_loss: 0.963 D_A_real_loss: 0.158 D_A_fake_loss: 0.157 D_B_real_loss: 0.215 D_B_fake_loss: 0.211
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 2000, time_from_last_report: 236.263, since_the_phase_start: 1179.641) G_gan_loss: 0.955 G_idt_loss: 0.540 G_cycle_loss: 0.972 D_A_real_loss: 0.158 D_A_fake_loss: 0.156 D_B_real_loss: 0.217 D_B_fake_loss: 0.214
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 2400, time_from_last_report: 235.207, since_the_phase_start: 1414.856) G_gan_loss: 1.055 G_idt_loss: 0.539 G_cycle_loss: 0.973 D_A_real_loss: 0.131 D_A_fake_loss: 0.125 D_B_real_loss: 0.217 D_B_fake_loss: 0.213
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 2800, time_from_last_report: 237.171, since_the_phase_start: 1652.034) G_gan_loss: 1.011 G_idt_loss: 0.539 G_cycle_loss: 0.968 D_A_real_loss: 0.173 D_A_fake_loss: 0.167 D_B_real_loss: 0.197 D_B_fake_loss: 0.194
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 3200, time_from_last_report: 235.950, since_the_phase_start: 1888.007) G_gan_loss: 1.045 G_idt_loss: 0.544 G_cycle_loss: 1.001 D_A_real_loss: 0.174 D_A_fake_loss: 0.172 D_B_real_loss: 0.182 D_B_fake_loss: 0.180
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 3600, time_from_last_report: 235.349, since_the_phase_start: 2123.373) G_gan_loss: 1.252 G_idt_loss: 0.553 G_cycle_loss: 1.154 D_A_real_loss: 0.169 D_A_fake_loss: 0.171 D_B_real_loss: 0.124 D_B_fake_loss: 0.132
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 4000, time_from_last_report: 234.433, since_the_phase_start: 2357.824) G_gan_loss: 1.009 G_idt_loss: 0.529 G_cycle_loss: 0.949 D_A_real_loss: 0.184 D_A_fake_loss: 0.186 D_B_real_loss: 0.181 D_B_fake_loss: 0.172
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 4400, time_from_last_report: 234.138, since_the_phase_start: 2591.972) G_gan_loss: 0.915 G_idt_loss: 0.523 G_cycle_loss: 0.885 D_A_real_loss: 0.186 D_A_fake_loss: 0.187 D_B_real_loss: 0.198 D_B_fake_loss: 0.191
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 4800, time_from_last_report: 235.205, since_the_phase_start: 2827.183) G_gan_loss: 0.887 G_idt_loss: 0.525 G_cycle_loss: 0.855 D_A_real_loss: 0.198 D_A_fake_loss: 0.194 D_B_real_loss: 0.208 D_B_fake_loss: 0.203
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 5200, time_from_last_report: 235.137, since_the_phase_start: 3062.314) G_gan_loss: 0.852 G_idt_loss: 0.520 G_cycle_loss: 0.831 D_A_real_loss: 0.205 D_A_fake_loss: 0.198 D_B_real_loss: 0.214 D_B_fake_loss: 0.209
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 5600, time_from_last_report: 234.845, since_the_phase_start: 3297.198) G_gan_loss: 0.832 G_idt_loss: 0.513 G_cycle_loss: 0.802 D_A_real_loss: 0.208 D_A_fake_loss: 0.203 D_B_real_loss: 0.221 D_B_fake_loss: 0.217
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 6000, time_from_last_report: 236.159, since_the_phase_start: 3533.360) G_gan_loss: 0.810 G_idt_loss: 0.515 G_cycle_loss: 0.785 D_A_real_loss: 0.211 D_A_fake_loss: 0.206 D_B_real_loss: 0.221 D_B_fake_loss: 0.216
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 6400, time_from_last_report: 237.401, since_the_phase_start: 3770.777) G_gan_loss: 0.898 G_idt_loss: 0.505 G_cycle_loss: 0.818 D_A_real_loss: 0.622 D_A_fake_loss: 0.602 D_B_real_loss: 0.224 D_B_fake_loss: 0.220
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 6800, time_from_last_report: 235.885, since_the_phase_start: 4006.695) G_gan_loss: 0.752 G_idt_loss: 0.500 G_cycle_loss: 0.751 D_A_real_loss: 0.281 D_A_fake_loss: 0.270 D_B_real_loss: 0.206 D_B_fake_loss: 0.208
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 7200, time_from_last_report: 233.319, since_the_phase_start: 4240.029) G_gan_loss: 0.735 G_idt_loss: 0.503 G_cycle_loss: 0.761 D_A_real_loss: 0.253 D_A_fake_loss: 0.248 D_B_real_loss: 0.205 D_B_fake_loss: 0.203
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 7600, time_from_last_report: 234.040, since_the_phase_start: 4474.088) G_gan_loss: 0.696 G_idt_loss: 0.499 G_cycle_loss: 0.705 D_A_real_loss: 0.228 D_A_fake_loss: 0.228 D_B_real_loss: 0.225 D_B_fake_loss: 0.222
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 8000, time_from_last_report: 234.023, since_the_phase_start: 4708.097) G_gan_loss: 0.746 G_idt_loss: 0.501 G_cycle_loss: 0.719 D_A_real_loss: 0.211 D_A_fake_loss: 0.211 D_B_real_loss: 0.227 D_B_fake_loss: 0.223
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 8400, time_from_last_report: 233.781, since_the_phase_start: 4941.911) G_gan_loss: 0.712 G_idt_loss: 0.496 G_cycle_loss: 0.694 D_A_real_loss: 0.217 D_A_fake_loss: 0.212 D_B_real_loss: 0.231 D_B_fake_loss: 0.228
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 8800, time_from_last_report: 233.892, since_the_phase_start: 5175.819) G_gan_loss: 0.710 G_idt_loss: 0.493 G_cycle_loss: 0.673 D_A_real_loss: 0.216 D_A_fake_loss: 0.214 D_B_real_loss: 0.234 D_B_fake_loss: 0.230
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 9200, time_from_last_report: 234.833, since_the_phase_start: 5410.642) G_gan_loss: 0.719 G_idt_loss: 0.502 G_cycle_loss: 0.670 D_A_real_loss: 0.220 D_A_fake_loss: 0.216 D_B_real_loss: 0.234 D_B_fake_loss: 0.231
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 9600, time_from_last_report: 235.429, since_the_phase_start: 5646.109) G_gan_loss: 0.690 G_idt_loss: 0.500 G_cycle_loss: 0.652 D_A_real_loss: 0.225 D_A_fake_loss: 0.223 D_B_real_loss: 0.236 D_B_fake_loss: 0.233
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 10000, time_from_last_report: 234.114, since_the_phase_start: 5880.245) G_gan_loss: 0.690 G_idt_loss: 0.495 G_cycle_loss: 0.634 D_A_real_loss: 0.230 D_A_fake_loss: 0.228 D_B_real_loss: 0.238 D_B_fake_loss: 0.234
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 10400, time_from_last_report: 233.687, since_the_phase_start: 6113.947) G_gan_loss: 0.674 G_idt_loss: 0.494 G_cycle_loss: 0.622 D_A_real_loss: 0.231 D_A_fake_loss: 0.229 D_B_real_loss: 0.238 D_B_fake_loss: 0.236
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 10800, time_from_last_report: 234.606, since_the_phase_start: 6348.528) G_gan_loss: 1.023 G_idt_loss: 0.503 G_cycle_loss: 0.707 D_A_real_loss: 0.145 D_A_fake_loss: 0.157 D_B_real_loss: 0.235 D_B_fake_loss: 0.233
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 11200, time_from_last_report: 237.420, since_the_phase_start: 6585.984) G_gan_loss: 0.840 G_idt_loss: 0.497 G_cycle_loss: 0.646 D_A_real_loss: 0.195 D_A_fake_loss: 0.202 D_B_real_loss: 0.237 D_B_fake_loss: 0.235
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 11600, time_from_last_report: 237.952, since_the_phase_start: 6823.951) G_gan_loss: 0.694 G_idt_loss: 0.492 G_cycle_loss: 0.614 D_A_real_loss: 0.225 D_A_fake_loss: 0.223 D_B_real_loss: 0.239 D_B_fake_loss: 0.237
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 12000, time_from_last_report: 235.676, since_the_phase_start: 7059.653) G_gan_loss: 0.692 G_idt_loss: 0.495 G_cycle_loss: 0.607 D_A_real_loss: 0.226 D_A_fake_loss: 0.223 D_B_real_loss: 0.238 D_B_fake_loss: 0.237
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 12400, time_from_last_report: 233.491, since_the_phase_start: 7293.167) G_gan_loss: 0.684 G_idt_loss: 0.491 G_cycle_loss: 0.594 D_A_real_loss: 0.227 D_A_fake_loss: 0.226 D_B_real_loss: 0.242 D_B_fake_loss: 0.240
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 12800, time_from_last_report: 234.909, since_the_phase_start: 7528.052) G_gan_loss: 0.691 G_idt_loss: 0.495 G_cycle_loss: 0.597 D_A_real_loss: 0.225 D_A_fake_loss: 0.224 D_B_real_loss: 0.241 D_B_fake_loss: 0.240
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 13200, time_from_last_report: 235.015, since_the_phase_start: 7763.091) G_gan_loss: 0.988 G_idt_loss: 0.512 G_cycle_loss: 0.996 D_A_real_loss: 0.514 D_A_fake_loss: 0.449 D_B_real_loss: 0.218 D_B_fake_loss: 0.216
# {'pre_used': [1], 'enchain_used': [1, 0], 'dechain_used': [0, 1], 'post_used': [1]}
# {'inputs_used': [5], 'chain_used': [5, 6]}
# (current_level: 2.000, iters: 13600, time_from_last_report: 234.029, since_the_phase_start: 7997.170) G_gan_loss: 0.644 G_idt_loss: 0.493 G_cycle_loss: 0.635 D_A_real_loss: 0.268 D_A_fake_loss: 0.260 D_B_real_loss: 0.233 D_B_fake_loss: 0.229
# ...
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 2000, time_from_last_report: 588.352, since_the_phase_start: 2947.061) G_gan_loss: 0.640 G_idt_loss: 0.508 G_cycle_loss: 0.616 D_A_real_loss: 0.235 D_A_fake_loss: 0.235 D_B_real_loss: 0.244 D_B_fake_loss: 0.243
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 2400, time_from_last_report: 588.062, since_the_phase_start: 3535.002) G_gan_loss: 0.641 G_idt_loss: 0.509 G_cycle_loss: 0.615 D_A_real_loss: 0.235 D_A_fake_loss: 0.235 D_B_real_loss: 0.245 D_B_fake_loss: 0.243
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 2800, time_from_last_report: 586.835, since_the_phase_start: 4121.887) G_gan_loss: 0.630 G_idt_loss: 0.512 G_cycle_loss: 0.609 D_A_real_loss: 0.238 D_A_fake_loss: 0.236 D_B_real_loss: 0.244 D_B_fake_loss: 0.243
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 3200, time_from_last_report: 590.010, since_the_phase_start: 4712.066) G_gan_loss: 0.639 G_idt_loss: 0.509 G_cycle_loss: 0.611 D_A_real_loss: 0.237 D_A_fake_loss: 0.236 D_B_real_loss: 0.244 D_B_fake_loss: 0.243
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 3600, time_from_last_report: 588.655, since_the_phase_start: 5300.664) G_gan_loss: 0.630 G_idt_loss: 0.508 G_cycle_loss: 0.609 D_A_real_loss: 0.239 D_A_fake_loss: 0.238 D_B_real_loss: 0.243 D_B_fake_loss: 0.242
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 4000, time_from_last_report: 589.157, since_the_phase_start: 5889.801) G_gan_loss: 0.631 G_idt_loss: 0.511 G_cycle_loss: 0.607 D_A_real_loss: 0.238 D_A_fake_loss: 0.237 D_B_real_loss: 0.244 D_B_fake_loss: 0.243
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 4400, time_from_last_report: 591.013, since_the_phase_start: 6480.856) G_gan_loss: 0.636 G_idt_loss: 0.508 G_cycle_loss: 0.610 D_A_real_loss: 0.237 D_A_fake_loss: 0.236 D_B_real_loss: 0.244 D_B_fake_loss: 0.243
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 4800, time_from_last_report: 590.273, since_the_phase_start: 7071.188) G_gan_loss: 0.634 G_idt_loss: 0.509 G_cycle_loss: 0.606 D_A_real_loss: 0.239 D_A_fake_loss: 0.239 D_B_real_loss: 0.245 D_B_fake_loss: 0.243
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 5200, time_from_last_report: 594.656, since_the_phase_start: 7665.912) G_gan_loss: 0.634 G_idt_loss: 0.504 G_cycle_loss: 0.609 D_A_real_loss: 0.239 D_A_fake_loss: 0.238 D_B_real_loss: 0.242 D_B_fake_loss: 0.241
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 5600, time_from_last_report: 593.896, since_the_phase_start: 8259.904) G_gan_loss: 0.639 G_idt_loss: 0.507 G_cycle_loss: 0.611 D_A_real_loss: 0.237 D_A_fake_loss: 0.236 D_B_real_loss: 0.243 D_B_fake_loss: 0.242
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 6000, time_from_last_report: 590.155, since_the_phase_start: 8850.118) G_gan_loss: 0.629 G_idt_loss: 0.509 G_cycle_loss: 0.600 D_A_real_loss: 0.240 D_A_fake_loss: 0.240 D_B_real_loss: 0.244 D_B_fake_loss: 0.242
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 6400, time_from_last_report: 588.478, since_the_phase_start: 9438.595) G_gan_loss: 0.634 G_idt_loss: 0.510 G_cycle_loss: 0.607 D_A_real_loss: 0.239 D_A_fake_loss: 0.238 D_B_real_loss: 0.242 D_B_fake_loss: 0.241
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 6800, time_from_last_report: 588.830, since_the_phase_start: 10027.480) G_gan_loss: 0.632 G_idt_loss: 0.509 G_cycle_loss: 0.602 D_A_real_loss: 0.240 D_A_fake_loss: 0.239 D_B_real_loss: 0.243 D_B_fake_loss: 0.242
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 7200, time_from_last_report: 590.618, since_the_phase_start: 10618.062) G_gan_loss: 0.631 G_idt_loss: 0.514 G_cycle_loss: 0.603 D_A_real_loss: 0.241 D_A_fake_loss: 0.240 D_B_real_loss: 0.242 D_B_fake_loss: 0.242
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 7600, time_from_last_report: 589.567, since_the_phase_start: 11207.660) G_gan_loss: 0.913 G_idt_loss: 0.527 G_cycle_loss: 0.760 D_A_real_loss: 0.177 D_A_fake_loss: 0.189 D_B_real_loss: 0.231 D_B_fake_loss: 0.228
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 8000, time_from_last_report: 590.611, since_the_phase_start: 11798.366) G_gan_loss: 0.958 G_idt_loss: 0.534 G_cycle_loss: 0.815 D_A_real_loss: 0.239 D_A_fake_loss: 0.224 D_B_real_loss: 0.226 D_B_fake_loss: 0.225
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 8400, time_from_last_report: 587.507, since_the_phase_start: 12385.795) G_gan_loss: 0.633 G_idt_loss: 0.513 G_cycle_loss: 0.671 D_A_real_loss: 0.243 D_A_fake_loss: 0.240 D_B_real_loss: 0.232 D_B_fake_loss: 0.230
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 8800, time_from_last_report: 591.046, since_the_phase_start: 12976.919) G_gan_loss: 0.659 G_idt_loss: 0.516 G_cycle_loss: 0.649 D_A_real_loss: 0.215 D_A_fake_loss: 0.216 D_B_real_loss: 0.236 D_B_fake_loss: 0.235
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 9200, time_from_last_report: 588.454, since_the_phase_start: 13565.475) G_gan_loss: 0.675 G_idt_loss: 0.514 G_cycle_loss: 0.639 D_A_real_loss: 0.216 D_A_fake_loss: 0.216 D_B_real_loss: 0.239 D_B_fake_loss: 0.237
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 9600, time_from_last_report: 589.308, since_the_phase_start: 14154.741) G_gan_loss: 0.666 G_idt_loss: 0.515 G_cycle_loss: 0.632 D_A_real_loss: 0.227 D_A_fake_loss: 0.226 D_B_real_loss: 0.239 D_B_fake_loss: 0.236
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 10000, time_from_last_report: 592.373, since_the_phase_start: 14747.136) G_gan_loss: 0.692 G_idt_loss: 0.517 G_cycle_loss: 0.649 D_A_real_loss: 0.223 D_A_fake_loss: 0.222 D_B_real_loss: 0.238 D_B_fake_loss: 0.236
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 10400, time_from_last_report: 590.323, since_the_phase_start: 15337.510) G_gan_loss: 0.765 G_idt_loss: 0.519 G_cycle_loss: 0.659 D_A_real_loss: 0.211 D_A_fake_loss: 0.214 D_B_real_loss: 0.236 D_B_fake_loss: 0.235
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 10800, time_from_last_report: 591.228, since_the_phase_start: 15928.823) G_gan_loss: 0.711 G_idt_loss: 0.513 G_cycle_loss: 0.662 D_A_real_loss: 0.219 D_A_fake_loss: 0.219 D_B_real_loss: 0.238 D_B_fake_loss: 0.236
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 11200, time_from_last_report: 588.506, since_the_phase_start: 16517.306) G_gan_loss: 0.678 G_idt_loss: 0.515 G_cycle_loss: 0.633 D_A_real_loss: 0.231 D_A_fake_loss: 0.229 D_B_real_loss: 0.238 D_B_fake_loss: 0.237
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 11600, time_from_last_report: 587.011, since_the_phase_start: 17104.360) G_gan_loss: 0.998 G_idt_loss: 0.526 G_cycle_loss: 0.800 D_A_real_loss: 0.169 D_A_fake_loss: 0.186 D_B_real_loss: 0.215 D_B_fake_loss: 0.212
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 12000, time_from_last_report: 592.186, since_the_phase_start: 17696.657) G_gan_loss: 1.011 G_idt_loss: 0.528 G_cycle_loss: 0.846 D_A_real_loss: 0.171 D_A_fake_loss: 0.170 D_B_real_loss: 0.193 D_B_fake_loss: 0.184
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 12400, time_from_last_report: 599.894, since_the_phase_start: 18296.475) G_gan_loss: 0.828 G_idt_loss: 0.518 G_cycle_loss: 0.717 D_A_real_loss: 0.210 D_A_fake_loss: 0.205 D_B_real_loss: 0.218 D_B_fake_loss: 0.215
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 12800, time_from_last_report: 593.833, since_the_phase_start: 18890.395) G_gan_loss: 0.767 G_idt_loss: 0.511 G_cycle_loss: 0.674 D_A_real_loss: 0.221 D_A_fake_loss: 0.218 D_B_real_loss: 0.224 D_B_fake_loss: 0.222
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 13200, time_from_last_report: 592.005, since_the_phase_start: 19482.475) G_gan_loss: 0.735 G_idt_loss: 0.515 G_cycle_loss: 0.656 D_A_real_loss: 0.223 D_A_fake_loss: 0.222 D_B_real_loss: 0.233 D_B_fake_loss: 0.229
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 13600, time_from_last_report: 592.596, since_the_phase_start: 20075.162) G_gan_loss: 0.719 G_idt_loss: 0.518 G_cycle_loss: 0.653 D_A_real_loss: 0.226 D_A_fake_loss: 0.224 D_B_real_loss: 0.232 D_B_fake_loss: 0.231
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 14000, time_from_last_report: 590.681, since_the_phase_start: 20665.781) G_gan_loss: 0.714 G_idt_loss: 0.513 G_cycle_loss: 0.650 D_A_real_loss: 0.228 D_A_fake_loss: 0.226 D_B_real_loss: 0.236 D_B_fake_loss: 0.233
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 14400, time_from_last_report: 594.794, since_the_phase_start: 21260.673) G_gan_loss: 0.707 G_idt_loss: 0.509 G_cycle_loss: 0.647 D_A_real_loss: 0.227 D_A_fake_loss: 0.226 D_B_real_loss: 0.235 D_B_fake_loss: 0.233
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 14800, time_from_last_report: 588.262, since_the_phase_start: 21849.025) G_gan_loss: 0.698 G_idt_loss: 0.514 G_cycle_loss: 0.640 D_A_real_loss: 0.233 D_A_fake_loss: 0.231 D_B_real_loss: 0.236 D_B_fake_loss: 0.233
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 15200, time_from_last_report: 592.002, since_the_phase_start: 22441.058) G_gan_loss: 0.694 G_idt_loss: 0.518 G_cycle_loss: 0.640 D_A_real_loss: 0.231 D_A_fake_loss: 0.230 D_B_real_loss: 0.236 D_B_fake_loss: 0.234
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 15600, time_from_last_report: 587.619, since_the_phase_start: 23028.708) G_gan_loss: 0.698 G_idt_loss: 0.513 G_cycle_loss: 0.641 D_A_real_loss: 0.232 D_A_fake_loss: 0.231 D_B_real_loss: 0.235 D_B_fake_loss: 0.233
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 16000, time_from_last_report: 590.254, since_the_phase_start: 23618.994) G_gan_loss: 0.693 G_idt_loss: 0.511 G_cycle_loss: 0.639 D_A_real_loss: 0.232 D_A_fake_loss: 0.231 D_B_real_loss: 0.237 D_B_fake_loss: 0.236
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 16400, time_from_last_report: 591.370, since_the_phase_start: 24210.254) G_gan_loss: 0.691 G_idt_loss: 0.515 G_cycle_loss: 0.634 D_A_real_loss: 0.233 D_A_fake_loss: 0.232 D_B_real_loss: 0.235 D_B_fake_loss: 0.234
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 16800, time_from_last_report: 590.769, since_the_phase_start: 24801.140) G_gan_loss: 0.690 G_idt_loss: 0.511 G_cycle_loss: 0.639 D_A_real_loss: 0.232 D_A_fake_loss: 0.231 D_B_real_loss: 0.237 D_B_fake_loss: 0.234
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 17200, time_from_last_report: 591.232, since_the_phase_start: 25392.484) G_gan_loss: 0.696 G_idt_loss: 0.513 G_cycle_loss: 0.641 D_A_real_loss: 0.232 D_A_fake_loss: 0.231 D_B_real_loss: 0.235 D_B_fake_loss: 0.234
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 17600, time_from_last_report: 590.005, since_the_phase_start: 25982.406) G_gan_loss: 0.695 G_idt_loss: 0.517 G_cycle_loss: 0.635 D_A_real_loss: 0.233 D_A_fake_loss: 0.231 D_B_real_loss: 0.234 D_B_fake_loss: 0.233
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 18000, time_from_last_report: 589.608, since_the_phase_start: 26572.076) G_gan_loss: 0.683 G_idt_loss: 0.512 G_cycle_loss: 0.632 D_A_real_loss: 0.236 D_A_fake_loss: 0.235 D_B_real_loss: 0.236 D_B_fake_loss: 0.234
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
# (current_level: 3.000, iters: 18400, time_from_last_report: 556.922, since_the_phase_start: 27129.147) G_gan_loss: 0.694 G_idt_loss: 0.512 G_cycle_loss: 0.637 D_A_real_loss: 0.232 D_A_fake_loss: 0.231 D_B_real_loss: 0.236 D_B_fake_loss: 0.235
# {'pre_used': [2], 'enchain_used': [2, 1, 0], 'dechain_used': [0, 1, 2], 'post_used': [2]}
# {'inputs_used': [4], 'chain_used': [4, 5, 6]}
